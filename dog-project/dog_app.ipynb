# %% [markdown]
# ## 卷积神经网络（Convolutional Neural Network, CNN）
#
# ## 项目：实现一个狗品种识别算法App
#
# 在这个notebook文件中，有些模板代码已经提供给你，但你还需要实现更多的功能来完成这个项目。除非有明确要求，你无须修改任何已给出的代码。以**'(练习)'**开始的标题表示接下来的代码部分中有你需要实现的功能。这些部分都配有详细的指导，需要实现的部分也会在注释中以'TODO'标出。请仔细阅读所有的提示。
#
# 除了实现代码外，你还**需要**回答一些与项目及代码相关的问题。每个需要回答的问题都会以 **'问题 X'** 标记。请仔细阅读每个问题，并且在问题后的 **'回答'** 部分写出完整的答案。我们将根据 你对问题的回答 和 撰写代码实现的功能 来对你提交的项目进行评分。
#
# >**提示：**Code 和 Markdown 区域可通过 **Shift + Enter** 快捷键运行。此外，Markdown可以通过双击进入编辑模式。
#
# 项目中显示为_选做_的部分可以帮助你的项目脱颖而出，而不是仅仅达到通过的最低要求。如果你决定追求更高的挑战，请在此 notebook 中完成_选做_部分的代码。
#
# ---
#
# ### 让我们开始吧
# 在这个notebook中，你将迈出第一步，来开发可以作为移动端或 Web应用程序一部分的算法。在这个项目的最后，你的程序将能够把用户提供的任何一个图像作为输入。如果可以从图像中检测到一只狗，它会输出对狗品种的预测。如果图像中是一个人脸，它会预测一个与其最相似的狗的种类。下面这张图展示了完成项目后可能的输出结果。（……实际上我们希望每个学生的输出结果不相同！）
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# 在现实世界中，你需要拼凑一系列的模型来完成不同的任务；举个例子，用来预测狗种类的算法会与预测人类的算法不同。在做项目的过程中，你可能会遇到不少失败的预测，因为并不存在完美的算法和模型。你最终提交的不完美的解决方案也一定会给你带来一个有趣的学习经验！
#
# ### 项目内容
#
# 我们将这个notebook分为不同的步骤，你可以使用下面的链接来浏览此notebook。
#
# * [Step 0](#step0): 导入数据集
# * [Step 1](#step1): 检测人脸
# * [Step 2](#step2): 检测狗狗
# * [Step 3](#step3): 从头创建一个CNN来分类狗品种
# * [Step 4](#step4): 使用一个CNN来区分狗的品种(使用迁移学习)
# * [Step 5](#step5): 建立一个CNN来分类狗的品种（使用迁移学习）
# * [Step 6](#step6): 完成你的算法
# * [Step 7](#step7): 测试你的算法
#
# 在该项目中包含了如下的问题：
#
# * [问题 1](#question1)
# * [问题 2](#question2)
# * [问题 3](#question3)
# * [问题 4](#question4)
# * [问题 5](#question5)
# * [问题 6](#question6)
# * [问题 7](#question7)
# * [问题 8](#question8)
# * [问题 9](#question9)
# * [问题 10](#question10)
# * [问题 11](#question11)
#
#
# ---
# <a id='step0'></a>
# ## 步骤 0: 导入数据集
#
# ### 导入狗数据集
# 在下方的代码单元（cell）中，我们导入了一个狗图像的数据集。我们使用 scikit-learn 库中的 `load_files` 函数来获取一些变量：
# - `train_files`, `valid_files`, `test_files` - 包含图像的文件路径的numpy数组
# - `train_targets`, `valid_targets`, `test_targets` - 包含独热编码分类标签的numpy数组
# - `dog_names` - 由字符串构成的与标签相对应的狗的种类

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# 定义函数来加载train，test和validation数据集
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# 加载train，test和validation数据集
train_files, train_targets = load_dataset('dogImages/train')
valid_files, valid_targets = load_dataset('dogImages/valid')
test_files, test_targets = load_dataset('dogImages/test')

# 加载狗品种列表
dog_names = [item[20:-1] for item in sorted(glob("dogImages/train/*/"))]

# 打印数据统计描述
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### 导入人脸数据集
#
# 在下方的代码单元中，我们导入人脸图像数据集，文件所在路径存储在名为 `human_files` 的 numpy 数组。

# %%
import random
random.seed(8675309)

# 加载打乱后的人脸数据集的文件名
human_files = np.array(glob("lfw/*/*"))
random.shuffle(human_files)

# 打印数据集的数据量
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## 步骤1：检测人脸
#
# 我们将使用 OpenCV 中的 [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) 来检测图像中的人脸。OpenCV 提供了很多预训练的人脸检测模型，它们以XML文件保存在 [github](https://github.com/opencv/opencv/tree/master/data/haarcascades)。我们已经下载了其中一个检测模型，并且把它存储在 `haarcascades` 的目录中。
#
# 在如下代码单元中，我们将演示如何使用这个检测模型在样本图像中找到人脸。

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# 提取预训练的人脸检测模型
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# 加载彩色（通道顺序为BGR）图像
img = cv2.imread(human_files[3])

# 将BGR图像进行灰度处理
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 在图像中找出脸
faces = face_cascade.detectMultiScale(gray)

# 打印图像中检测到的脸的个数
print('Number of faces detected:', len(faces))

# 获取每一个所检测到的脸的识别框
for (x,y,w,h) in faces:
    # 在人脸图像中绘制出识别框
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# 将BGR图像转变为RGB图像以打印
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# 展示含有识别框的图像
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# 在使用任何一个检测模型之前，将图像转换为灰度图是常用过程。`detectMultiScale` 函数使用储存在 `face_cascade` 中的的数据，对输入的灰度图像进行分类。
#
# 在上方的代码中，`faces` 以 numpy 数组的形式，保存了识别到的面部信息。它其中每一行表示一个被检测到的脸，该数据包括如下四个信息：前两个元素  `x`、`y` 代表识别框左上角的 x 和 y 坐标（参照上图，注意 y 坐标的方向和我们默认的方向不同）；后两个元素代表识别框在 x 和 y 轴两个方向延伸的长度 `w` 和 `d`。
#
# ### 写一个人脸识别器
#
# 我们可以将这个程序封装为一个函数。该函数的输入为人脸图像的**路径**，当图像中包含人脸时，该函数返回 `True`，反之返回 `False`。该函数定义如下所示。

# %%
# 如果img_path路径表示的图像检测到了脸，返回"True" 
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### **【练习】** 评估人脸检测模型

# %% [markdown]
# ---
#
# <a id='question1'></a>
# ### __问题 1:__
#
# 在下方的代码块中，使用 `face_detector` 函数，计算：
#
# - `human_files` 的前100张图像中，能够检测到**人脸**的图像占比多少？
# - `dog_files` 的前100张图像中，能够检测到**人脸**的图像占比多少？
#
# 理想情况下，人图像中检测到人脸的概率应当为100%，而狗图像中检测到人脸的概率应该为0%。你会发现我们的算法并非完美，但结果仍然是可以接受的。我们从每个数据集中提取前100个图像的文件路径，并将它们存储在`human_files_short`和`dog_files_short`中。

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
## 请不要修改上方代码


## TODO: 基于human_files_short和dog_files_short
## 中的图像测试face_detector的表现
human_detected = [h for h in human_files_short if face_detector(h)]
human_pc = len(human_detected) * 1.
print("Human percentage: {}%".format(human_pc))
dog_detected = [d for d in dog_files_short if face_detector(d)]
dog_pc = len(dog_detected) * 1.
print("Dog percentage: {}%".format(dog_pc))
# Out:
# Human percentage: 99.0%
# Dog percentage: 11.0%

# %% [markdown]
# ---
#
# <a id='question2'></a>
#
# ### __问题 2:__
#
# 就算法而言，该算法成功与否的关键在于，用户能否提供含有清晰面部特征的人脸图像。
# 那么你认为，这样的要求在实际使用中对用户合理吗？如果你觉得不合理，你能否想到一个方法，即使图像中并没有清晰的面部特征，也能够检测到人脸？
#
# __回答:__

# %% [markdown]
# 在实际生活中并不一定能提供面部清晰的人脸图像，这样的要求在现实中或许不太合理。如果没有清晰的图像也要检测到人脸的话可能需要重新建立openCV，不过这会相当耗时，在这个的例子证明，运行在一个微小的图像数据集）上，用有300多个时期，准确率达到97.5％。不过这个算法不更改任何东西重复运行每一次训练的准确度都会不一样，最高高达99%，最低只有50%

# %% [markdown]
# ---
#
# <a id='Selection1'></a>
# ### 选做：
#
# 我们建议在你的算法中使用opencv的人脸检测模型去检测人类图像，不过你可以自由地探索其他的方法，尤其是尝试使用深度学习来解决它:)。请用下方的代码单元来设计和测试你的面部监测算法。如果你决定完成这个_选做_任务，你需要报告算法在每一个数据集上的表现。

# %%
## (选做) TODO: 报告另一个面部检测算法在LFW数据集上的表现
### 你可以随意使用所需的代码单元数
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint

def load_resized(img_path):
    #print("Img: {}".format(img_path))
    img = cv2.imread(img_path)
    return cv2.resize(img, (224, 224))

humans_X = [load_resized(i) for i in human_files]
dogs_X = [load_resized(i) for i in train_files]
humans_X_short = humans_X[:200]
dogs_X_short = dogs_X[:200]

humans_y = []
for x in humans_X_short:
    humans_y.append([1, 0])
    
humans_y = np.array(humans_y, dtype=np.float32)

dogs_y = []
for x in dogs_X_short:
    dogs_y.append([0, 1])
dogs_y = np.array(dogs_y, dtype=np.float32)

dvh_X = np.concatenate((humans_X_short, dogs_X_short), axis=0)
dvh_y = np.concatenate((humans_y, dogs_y), axis=0)
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=(10, 10), input_shape=(224, 224, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2), padding='same'))
model.add(Conv2D(filters=32, kernel_size=(7, 7)))
model.add(Activation("sigmoid"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(1,1), padding='same'))
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.2))
model.add(Dense(120))
model.add(Activation("relu"))
model.add(Dense(2))
model.add(Activation("softmax"))
model.summary()

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

epochs = 300

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.dogs_vs_humans.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(dvh_X, dvh_y,
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 215, 215, 16)      4816
# _________________________________________________________________
# activation_1 (Activation)    (None, 215, 215, 16)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 108, 108, 16)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 102, 102, 32)      25120
# _________________________________________________________________
# activation_2 (Activation)    (None, 102, 102, 32)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 102, 102, 32)      0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 32)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 120)               3960
# _________________________________________________________________
# activation_3 (Activation)    (None, 120)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 242
# _________________________________________________________________
# activation_4 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 34,138.0
# Trainable params: 34,138.0
# Non-trainable params: 0.0
# _________________________________________________________________
# Epoch 1/300
# 400/400 [==============================] - 4s - loss: 0.7712 - acc: 0.5300
# Epoch 2/300
#  40/400 [==>...........................] - ETA: 1s - loss: 0.7155 - acc: 0.5000
# /home/carnd/anaconda3/envs/dog-project/lib/python3.6/site-packages/keras/callbacks.py:388: RuntimeWarning: Can save best model only with val_loss available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# 400/400 [==============================] - 1s - loss: 0.7109 - acc: 0.4800
# Epoch 3/300
# 400/400 [==============================] - 1s - loss: 0.7046 - acc: 0.5000
# Epoch 4/300
# 400/400 [==============================] - 1s - loss: 0.6889 - acc: 0.5700
# Epoch 5/300
# 400/400 [==============================] - 1s - loss: 0.6950 - acc: 0.5225
# Epoch 6/300
# 400/400 [==============================] - 1s - loss: 0.6865 - acc: 0.5575
# Epoch 7/300
# 400/400 [==============================] - 1s - loss: 0.6844 - acc: 0.5800
# Epoch 8/300
# 400/400 [==============================] - 1s - loss: 0.6532 - acc: 0.6550
# Epoch 9/300
# 400/400 [==============================] - 1s - loss: 0.6487 - acc: 0.6575
# Epoch 10/300
# 400/400 [==============================] - 1s - loss: 0.6631 - acc: 0.6075
# Epoch 11/300
# 400/400 [==============================] - 1s - loss: 0.6305 - acc: 0.6350
# Epoch 12/300
# 400/400 [==============================] - 1s - loss: 0.6481 - acc: 0.6575
# Epoch 13/300
# 400/400 [==============================] - 1s - loss: 0.6039 - acc: 0.7100
# Epoch 14/300
# 400/400 [==============================] - 1s - loss: 0.6268 - acc: 0.6650
# Epoch 15/300
# 400/400 [==============================] - 1s - loss: 0.6044 - acc: 0.6925
# Epoch 16/300
# 400/400 [==============================] - 1s - loss: 0.5960 - acc: 0.7200
# Epoch 17/300
# 400/400 [==============================] - 1s - loss: 0.5823 - acc: 0.7175
# Epoch 18/300
# 400/400 [==============================] - 1s - loss: 0.5635 - acc: 0.7275
# Epoch 19/300
# 400/400 [==============================] - 1s - loss: 0.5496 - acc: 0.7450
# Epoch 20/300
# 400/400 [==============================] - 1s - loss: 0.6216 - acc: 0.6825
# Epoch 21/300
# 400/400 [==============================] - 1s - loss: 0.5736 - acc: 0.7225
# Epoch 22/300
# 400/400 [==============================] - 1s - loss: 0.5511 - acc: 0.7500
# Epoch 23/300
# 400/400 [==============================] - 1s - loss: 0.5294 - acc: 0.7700
# Epoch 24/300
# 400/400 [==============================] - 1s - loss: 0.5592 - acc: 0.7150
# Epoch 25/300
# 400/400 [==============================] - 1s - loss: 0.5443 - acc: 0.7650
# Epoch 26/300
# 400/400 [==============================] - 1s - loss: 0.5244 - acc: 0.7750
# Epoch 27/300
# 400/400 [==============================] - 1s - loss: 0.5044 - acc: 0.7700
# Epoch 28/300
# 400/400 [==============================] - 1s - loss: 0.4887 - acc: 0.7925
# Epoch 29/300
# 400/400 [==============================] - 1s - loss: 0.5136 - acc: 0.7725
# Epoch 30/300
# 400/400 [==============================] - 1s - loss: 0.5386 - acc: 0.7625
# Epoch 31/300
# 400/400 [==============================] - 1s - loss: 0.5063 - acc: 0.7750
# Epoch 32/300
# 400/400 [==============================] - 1s - loss: 0.4919 - acc: 0.7925
# Epoch 33/300
# 400/400 [==============================] - 1s - loss: 0.5070 - acc: 0.7575
# Epoch 34/300
# 400/400 [==============================] - 1s - loss: 0.4741 - acc: 0.7975
# Epoch 35/300
# 400/400 [==============================] - 1s - loss: 0.4819 - acc: 0.7825
# Epoch 36/300
# 400/400 [==============================] - 1s - loss: 0.4848 - acc: 0.7800
# Epoch 37/300
# 400/400 [==============================] - 1s - loss: 0.4638 - acc: 0.7900
# Epoch 38/300
# 400/400 [==============================] - 1s - loss: 0.4653 - acc: 0.7850
# Epoch 39/300
# 400/400 [==============================] - 1s - loss: 0.4517 - acc: 0.7950
# Epoch 40/300
# 400/400 [==============================] - 1s - loss: 0.4779 - acc: 0.7775
# Epoch 41/300
# 400/400 [==============================] - 1s - loss: 0.4376 - acc: 0.7925
# Epoch 42/300
# 400/400 [==============================] - 1s - loss: 0.4449 - acc: 0.8150
# Epoch 43/300
# 400/400 [==============================] - 1s - loss: 0.4154 - acc: 0.8175
# Epoch 44/300
# 400/400 [==============================] - 1s - loss: 0.3990 - acc: 0.8150
# Epoch 45/300
# 400/400 [==============================] - 1s - loss: 0.4461 - acc: 0.8000
# Epoch 46/300
# 400/400 [==============================] - 1s - loss: 0.4448 - acc: 0.8100
# Epoch 47/300
# 400/400 [==============================] - 1s - loss: 0.4425 - acc: 0.8000
# Epoch 48/300
# 400/400 [==============================] - 1s - loss: 0.4343 - acc: 0.8050
# Epoch 49/300
# 400/400 [==============================] - 1s - loss: 0.4082 - acc: 0.8475
# Epoch 50/300
# 400/400 [==============================] - 1s - loss: 0.4496 - acc: 0.7875
# Epoch 51/300
# 400/400 [==============================] - 1s - loss: 0.4173 - acc: 0.7950
# Epoch 52/300
# 400/400 [==============================] - 1s - loss: 0.4076 - acc: 0.8125
# Epoch 53/300
# 400/400 [==============================] - 1s - loss: 0.4341 - acc: 0.8050
# Epoch 54/300
# 400/400 [==============================] - 1s - loss: 0.4332 - acc: 0.8000
# Epoch 55/300
# 400/400 [==============================] - 1s - loss: 0.3955 - acc: 0.8200
# Epoch 56/300
# 400/400 [==============================] - 1s - loss: 0.3766 - acc: 0.8350
# Epoch 57/300
# 400/400 [==============================] - 1s - loss: 0.3973 - acc: 0.8200
# Epoch 58/300
# 400/400 [==============================] - 1s - loss: 0.3714 - acc: 0.8475
# Epoch 59/300
# 400/400 [==============================] - 1s - loss: 0.3897 - acc: 0.8300
# Epoch 60/300
# 400/400 [==============================] - 1s - loss: 0.3705 - acc: 0.8400
# Epoch 61/300
# 400/400 [==============================] - 1s - loss: 0.3383 - acc: 0.8325
# Epoch 62/300
# 400/400 [==============================] - 1s - loss: 0.3950 - acc: 0.8275
# Epoch 63/300
# 400/400 [==============================] - 1s - loss: 0.3629 - acc: 0.8325
# Epoch 64/300
# 400/400 [==============================] - 1s - loss: 0.3467 - acc: 0.8475
# Epoch 65/300
# 400/400 [==============================] - 1s - loss: 0.3654 - acc: 0.8400
# Epoch 66/300
# 400/400 [==============================] - 1s - loss: 0.3408 - acc: 0.8450
# Epoch 67/300
# 400/400 [==============================] - 1s - loss: 0.3769 - acc: 0.8375
# Epoch 68/300
# 400/400 [==============================] - 1s - loss: 0.3456 - acc: 0.8250
# Epoch 69/300
# 400/400 [==============================] - 1s - loss: 0.3455 - acc: 0.8450
# Epoch 70/300
# 400/400 [==============================] - 1s - loss: 0.3365 - acc: 0.8575
# Epoch 71/300
# 400/400 [==============================] - 1s - loss: 0.3346 - acc: 0.8450
# Epoch 72/300
# 400/400 [==============================] - 1s - loss: 0.3509 - acc: 0.8550
# Epoch 73/300
# 400/400 [==============================] - 1s - loss: 0.3344 - acc: 0.8550
# Epoch 74/300
# 400/400 [==============================] - 1s - loss: 0.3478 - acc: 0.8275
# Epoch 75/300
# 400/400 [==============================] - 1s - loss: 0.3539 - acc: 0.8300
# Epoch 76/300
# 400/400 [==============================] - 1s - loss: 0.3347 - acc: 0.8425
# Epoch 77/300
# 400/400 [==============================] - 1s - loss: 0.3482 - acc: 0.8325
# Epoch 78/300
# 400/400 [==============================] - 1s - loss: 0.3506 - acc: 0.8500
# Epoch 79/300
# 400/400 [==============================] - 1s - loss: 0.3123 - acc: 0.8725
# Epoch 80/300
# 400/400 [==============================] - 1s - loss: 0.3772 - acc: 0.8475
# Epoch 81/300
# 400/400 [==============================] - 1s - loss: 0.3440 - acc: 0.8450
# Epoch 82/300
# 400/400 [==============================] - 1s - loss: 0.3475 - acc: 0.8600
# Epoch 83/300
# 400/400 [==============================] - 1s - loss: 0.3003 - acc: 0.8725
# Epoch 84/300
# 400/400 [==============================] - 1s - loss: 0.3383 - acc: 0.8600
# Epoch 85/300
# 400/400 [==============================] - 1s - loss: 0.3048 - acc: 0.8600
# Epoch 86/300
# 400/400 [==============================] - 1s - loss: 0.3279 - acc: 0.8550
# Epoch 87/300
# 400/400 [==============================] - 1s - loss: 0.3278 - acc: 0.8550
# Epoch 88/300
# 400/400 [==============================] - 1s - loss: 0.3167 - acc: 0.8650
# Epoch 89/300
# 400/400 [==============================] - 1s - loss: 0.3240 - acc: 0.8700
# Epoch 90/300
# 400/400 [==============================] - 1s - loss: 0.3186 - acc: 0.8675
# Epoch 91/300
# 400/400 [==============================] - 1s - loss: 0.2843 - acc: 0.8825
# Epoch 92/300
# 400/400 [==============================] - 1s - loss: 0.3546 - acc: 0.8375
# Epoch 93/300
# 400/400 [==============================] - 1s - loss: 0.3337 - acc: 0.8550
# Epoch 94/300
# 400/400 [==============================] - 1s - loss: 0.3041 - acc: 0.8725
# Epoch 95/300
# 400/400 [==============================] - 1s - loss: 0.3254 - acc: 0.8650
# Epoch 96/300
# 400/400 [==============================] - 1s - loss: 0.3316 - acc: 0.8600
# Epoch 97/300
# 400/400 [==============================] - 1s - loss: 0.2769 - acc: 0.8700
# Epoch 98/300
# 400/400 [==============================] - 1s - loss: 0.3400 - acc: 0.8550
# Epoch 99/300
# 400/400 [==============================] - 1s - loss: 0.2863 - acc: 0.8750
# Epoch 100/300
# 400/400 [==============================] - 1s - loss: 0.3201 - acc: 0.8650
# Epoch 101/300
# 400/400 [==============================] - 1s - loss: 0.2655 - acc: 0.9000
# Epoch 102/300
# 400/400 [==============================] - 1s - loss: 0.3050 - acc: 0.8750
# Epoch 103/300
# 400/400 [==============================] - 1s - loss: 0.2759 - acc: 0.8700
# Epoch 104/300
# 400/400 [==============================] - 1s - loss: 0.3207 - acc: 0.8625
# Epoch 105/300
# 400/400 [==============================] - 1s - loss: 0.2887 - acc: 0.8900
# Epoch 106/300
# 400/400 [==============================] - 1s - loss: 0.3057 - acc: 0.8750
# Epoch 107/300
# 400/400 [==============================] - 1s - loss: 0.2848 - acc: 0.8875
# Epoch 108/300
# 400/400 [==============================] - 1s - loss: 0.3093 - acc: 0.8575
# Epoch 109/300
# 400/400 [==============================] - 1s - loss: 0.2879 - acc: 0.8650
# Epoch 110/300
# 400/400 [==============================] - 1s - loss: 0.2992 - acc: 0.8775
# Epoch 111/300
# 400/400 [==============================] - 1s - loss: 0.3324 - acc: 0.8675
# Epoch 112/300
# 400/400 [==============================] - 1s - loss: 0.2824 - acc: 0.8775
# Epoch 113/300
# 400/400 [==============================] - 1s - loss: 0.2997 - acc: 0.8775
# Epoch 114/300
# 400/400 [==============================] - 1s - loss: 0.2773 - acc: 0.8825
# Epoch 115/300
# 400/400 [==============================] - 1s - loss: 0.2856 - acc: 0.8775
# Epoch 116/300
# 400/400 [==============================] - 1s - loss: 0.3324 - acc: 0.8750
# Epoch 117/300
# 400/400 [==============================] - 1s - loss: 0.2703 - acc: 0.8950
# Epoch 118/300
# 400/400 [==============================] - 1s - loss: 0.2736 - acc: 0.8750
# Epoch 119/300
# 400/400 [==============================] - 1s - loss: 0.2576 - acc: 0.8900
# Epoch 120/300
# 400/400 [==============================] - 1s - loss: 0.3149 - acc: 0.8750
# Epoch 121/300
# 400/400 [==============================] - 1s - loss: 0.3050 - acc: 0.8725
# Epoch 122/300
# 400/400 [==============================] - 1s - loss: 0.3298 - acc: 0.8450
# Epoch 123/300
# 400/400 [==============================] - 1s - loss: 0.2864 - acc: 0.8875
# Epoch 124/300
# 400/400 [==============================] - 1s - loss: 0.2661 - acc: 0.9025
# Epoch 125/300
# 400/400 [==============================] - 1s - loss: 0.3081 - acc: 0.8700
# Epoch 126/300
# 400/400 [==============================] - 1s - loss: 0.2520 - acc: 0.8950
# Epoch 127/300
# 400/400 [==============================] - 1s - loss: 0.2829 - acc: 0.8975
# Epoch 128/300
# 400/400 [==============================] - 1s - loss: 0.2618 - acc: 0.9000
# Epoch 129/300
# 400/400 [==============================] - 1s - loss: 0.2635 - acc: 0.8725
# Epoch 130/300
# 400/400 [==============================] - 1s - loss: 0.2557 - acc: 0.9000
# Epoch 131/300
# 400/400 [==============================] - 1s - loss: 0.2422 - acc: 0.8875
# Epoch 132/300
# 400/400 [==============================] - 1s - loss: 0.4968 - acc: 0.8650
# Epoch 133/300
# 400/400 [==============================] - 1s - loss: 0.2620 - acc: 0.9000
# Epoch 134/300
# 400/400 [==============================] - 1s - loss: 0.2415 - acc: 0.8975
# Epoch 135/300
# 400/400 [==============================] - 1s - loss: 0.2623 - acc: 0.8775
# Epoch 136/300
# 400/400 [==============================] - 1s - loss: 0.2718 - acc: 0.8750
# Epoch 137/300
# 400/400 [==============================] - 1s - loss: 0.2695 - acc: 0.8775
# Epoch 138/300
# 400/400 [==============================] - 1s - loss: 0.2573 - acc: 0.9150
# Epoch 139/300
# 400/400 [==============================] - 1s - loss: 0.4007 - acc: 0.8275
# Epoch 140/300
# 400/400 [==============================] - 1s - loss: 0.2927 - acc: 0.8650
# Epoch 141/300
# 400/400 [==============================] - 1s - loss: 0.2340 - acc: 0.9150
# Epoch 142/300
# 400/400 [==============================] - 1s - loss: 0.2752 - acc: 0.8950
# Epoch 143/300
# 400/400 [==============================] - 1s - loss: 0.3295 - acc: 0.8575
# Epoch 144/300
# 400/400 [==============================] - 1s - loss: 0.2540 - acc: 0.8950
# Epoch 145/300
# 400/400 [==============================] - 1s - loss: 0.2601 - acc: 0.8800
# Epoch 146/300
# 400/400 [==============================] - 1s - loss: 0.2539 - acc: 0.8850
# Epoch 147/300
# 400/400 [==============================] - 1s - loss: 0.2334 - acc: 0.9025
# Epoch 148/300
# 400/400 [==============================] - 1s - loss: 0.2691 - acc: 0.8750
# Epoch 149/300
# 400/400 [==============================] - 1s - loss: 0.2988 - acc: 0.8825
# Epoch 150/300
# 400/400 [==============================] - 1s - loss: 0.2364 - acc: 0.9000
# Epoch 151/300
# 400/400 [==============================] - 1s - loss: 0.2618 - acc: 0.8850
# Epoch 152/300
# 400/400 [==============================] - 1s - loss: 0.2631 - acc: 0.8875
# Epoch 153/300
# 400/400 [==============================] - 1s - loss: 0.2699 - acc: 0.8825
# Epoch 154/300
# 400/400 [==============================] - 1s - loss: 0.1970 - acc: 0.9250
# Epoch 155/300
# 400/400 [==============================] - 1s - loss: 0.2621 - acc: 0.8850
# Epoch 156/300
# 400/400 [==============================] - 1s - loss: 0.2355 - acc: 0.9000
# Epoch 157/300
# 400/400 [==============================] - 1s - loss: 0.2668 - acc: 0.8850
# Epoch 158/300
# 400/400 [==============================] - 1s - loss: 0.2634 - acc: 0.8900
# Epoch 159/300
# 400/400 [==============================] - 1s - loss: 0.2583 - acc: 0.8975
# Epoch 160/300
# 400/400 [==============================] - 1s - loss: 0.2445 - acc: 0.9075
# Epoch 161/300
# 400/400 [==============================] - 1s - loss: 0.2240 - acc: 0.9050
# Epoch 162/300
# 400/400 [==============================] - 1s - loss: 0.2508 - acc: 0.8850
# Epoch 163/300
# 400/400 [==============================] - 1s - loss: 0.2347 - acc: 0.9075
# Epoch 164/300
# 400/400 [==============================] - 1s - loss: 0.2656 - acc: 0.8875
# Epoch 165/300
# 400/400 [==============================] - 1s - loss: 0.2340 - acc: 0.9150
# Epoch 166/300
# 400/400 [==============================] - 1s - loss: 0.2276 - acc: 0.8950
# Epoch 167/300
# 400/400 [==============================] - 1s - loss: 0.3092 - acc: 0.8775
# Epoch 168/300
# 400/400 [==============================] - 1s - loss: 0.2256 - acc: 0.9100
# Epoch 169/300
# 400/400 [==============================] - 1s - loss: 0.2696 - acc: 0.8875
# Epoch 170/300
# 400/400 [==============================] - 1s - loss: 0.2250 - acc: 0.9175
# Epoch 171/300
# 400/400 [==============================] - 1s - loss: 0.2832 - acc: 0.8900
# Epoch 172/300
# 400/400 [==============================] - 1s - loss: 0.2195 - acc: 0.9125
# Epoch 173/300
# 400/400 [==============================] - 1s - loss: 0.2308 - acc: 0.9075
# Epoch 174/300
# 400/400 [==============================] - 1s - loss: 0.3124 - acc: 0.8675
# Epoch 175/300
# 400/400 [==============================] - 1s - loss: 0.2741 - acc: 0.8825
# Epoch 176/300
# 400/400 [==============================] - 1s - loss: 0.2500 - acc: 0.8925
# Epoch 177/300
# 400/400 [==============================] - 1s - loss: 0.2509 - acc: 0.8900
# Epoch 178/300
# 400/400 [==============================] - 1s - loss: 0.2144 - acc: 0.9125
# Epoch 179/300
# 400/400 [==============================] - 1s - loss: 0.2266 - acc: 0.8975
# Epoch 180/300
# 400/400 [==============================] - 1s - loss: 0.2375 - acc: 0.9025
# Epoch 181/300
# 400/400 [==============================] - 1s - loss: 0.2449 - acc: 0.9050
# Epoch 182/300
# 400/400 [==============================] - 1s - loss: 0.2548 - acc: 0.9000
# Epoch 183/300
# 400/400 [==============================] - 1s - loss: 0.2512 - acc: 0.8925
# Epoch 184/300
# 400/400 [==============================] - 1s - loss: 0.2071 - acc: 0.9100
# Epoch 185/300
# 400/400 [==============================] - 1s - loss: 0.2550 - acc: 0.8900
# Epoch 186/300
# 400/400 [==============================] - 1s - loss: 0.2037 - acc: 0.9175
# Epoch 187/300
# 400/400 [==============================] - 1s - loss: 0.2609 - acc: 0.8925
# Epoch 188/300
# 400/400 [==============================] - 1s - loss: 0.1772 - acc: 0.9225
# Epoch 189/300
# 400/400 [==============================] - 1s - loss: 0.2319 - acc: 0.9075
# Epoch 190/300
# 400/400 [==============================] - 1s - loss: 0.2152 - acc: 0.9025
# Epoch 191/300
# 400/400 [==============================] - 1s - loss: 0.2683 - acc: 0.8975
# Epoch 192/300
# 400/400 [==============================] - 1s - loss: 0.1976 - acc: 0.9150
# Epoch 193/300
# 400/400 [==============================] - 1s - loss: 0.2508 - acc: 0.9075
# Epoch 194/300
# 400/400 [==============================] - 1s - loss: 0.2123 - acc: 0.9125
# Epoch 195/300
# 400/400 [==============================] - 1s - loss: 0.2704 - acc: 0.8975
# Epoch 196/300
# 400/400 [==============================] - 1s - loss: 0.2078 - acc: 0.9200
# Epoch 197/300
# 400/400 [==============================] - 1s - loss: 0.2608 - acc: 0.8950
# Epoch 198/300
# 400/400 [==============================] - 1s - loss: 0.2197 - acc: 0.9075
# Epoch 199/300
# 400/400 [==============================] - 1s - loss: 0.2033 - acc: 0.9175
# Epoch 200/300
# 400/400 [==============================] - 1s - loss: 0.2350 - acc: 0.8875
# Epoch 201/300
# 400/400 [==============================] - 1s - loss: 0.2523 - acc: 0.9000
# Epoch 202/300
# 400/400 [==============================] - 1s - loss: 0.2202 - acc: 0.9150
# Epoch 203/300
# 400/400 [==============================] - 1s - loss: 0.2155 - acc: 0.9075
# Epoch 204/300
# 400/400 [==============================] - 1s - loss: 0.2479 - acc: 0.8850
# Epoch 205/300
# 400/400 [==============================] - 1s - loss: 0.2063 - acc: 0.9150
# Epoch 206/300
# 400/400 [==============================] - 1s - loss: 0.5689 - acc: 0.8700
# Epoch 207/300
# 400/400 [==============================] - 1s - loss: 0.2380 - acc: 0.9025
# Epoch 208/300
# 400/400 [==============================] - 1s - loss: 0.2251 - acc: 0.9150
# Epoch 209/300
# 400/400 [==============================] - 1s - loss: 0.2278 - acc: 0.9150
# Epoch 210/300
# 400/400 [==============================] - 1s - loss: 0.2447 - acc: 0.8950
# Epoch 211/300
# 400/400 [==============================] - 1s - loss: 0.3173 - acc: 0.9000
# Epoch 212/300
# 400/400 [==============================] - 1s - loss: 0.2131 - acc: 0.9225
# Epoch 213/300
# 400/400 [==============================] - 1s - loss: 0.1995 - acc: 0.9150
# Epoch 214/300
# 400/400 [==============================] - 1s - loss: 0.2275 - acc: 0.8900
# Epoch 215/300
# 400/400 [==============================] - 1s - loss: 0.2378 - acc: 0.9050
# Epoch 216/300
# 400/400 [==============================] - 1s - loss: 0.3171 - acc: 0.8800
# Epoch 217/300
# 400/400 [==============================] - 1s - loss: 0.1877 - acc: 0.9225
# Epoch 218/300
# 400/400 [==============================] - 1s - loss: 0.3900 - acc: 0.8850
# Epoch 219/300
# 400/400 [==============================] - 1s - loss: 0.1985 - acc: 0.9225
# Epoch 220/300
# 400/400 [==============================] - 1s - loss: 0.2198 - acc: 0.9125
# Epoch 221/300
# 400/400 [==============================] - 1s - loss: 0.2352 - acc: 0.8925
# Epoch 222/300
# 400/400 [==============================] - 1s - loss: 0.2441 - acc: 0.9150
# Epoch 223/300
# 400/400 [==============================] - 1s - loss: 0.1992 - acc: 0.9300
# Epoch 224/300
# 400/400 [==============================] - 1s - loss: 0.2340 - acc: 0.8925
# Epoch 225/300
# 400/400 [==============================] - 1s - loss: 0.2518 - acc: 0.8925
# Epoch 226/300
# 400/400 [==============================] - 1s - loss: 0.1914 - acc: 0.9200
# Epoch 227/300
# 400/400 [==============================] - 1s - loss: 0.2414 - acc: 0.8875
# Epoch 228/300
# 400/400 [==============================] - 1s - loss: 0.1912 - acc: 0.9250
# Epoch 229/300
# 400/400 [==============================] - 1s - loss: 0.2033 - acc: 0.9125
# Epoch 230/300
# 400/400 [==============================] - 1s - loss: 0.2462 - acc: 0.8925
# Epoch 231/300
# 400/400 [==============================] - 1s - loss: 0.1911 - acc: 0.9225
# Epoch 232/300
# 400/400 [==============================] - 1s - loss: 0.2353 - acc: 0.9150
# Epoch 233/300
# 400/400 [==============================] - 1s - loss: 0.2148 - acc: 0.9075
# Epoch 234/300
# 400/400 [==============================] - 1s - loss: 0.2649 - acc: 0.9150
# Epoch 235/300
# 400/400 [==============================] - 1s - loss: 0.1989 - acc: 0.9200
# Epoch 236/300
# 400/400 [==============================] - 1s - loss: 0.2308 - acc: 0.9175
# Epoch 237/300
# 400/400 [==============================] - 1s - loss: 0.2204 - acc: 0.9225
# Epoch 238/300
# 400/400 [==============================] - 1s - loss: 0.1862 - acc: 0.9275
# Epoch 239/300
# 400/400 [==============================] - 1s - loss: 0.1842 - acc: 0.9325
# Epoch 240/300
# 400/400 [==============================] - 1s - loss: 0.2478 - acc: 0.9125
# Epoch 241/300
# 400/400 [==============================] - 1s - loss: 0.3158 - acc: 0.9050
# Epoch 242/300
# 400/400 [==============================] - 1s - loss: 0.1960 - acc: 0.9200
# Epoch 243/300
# 400/400 [==============================] - 1s - loss: 0.2045 - acc: 0.9050
# Epoch 244/300
# 400/400 [==============================] - 1s - loss: 0.2592 - acc: 0.8925
# Epoch 245/300
# 400/400 [==============================] - 1s - loss: 0.1824 - acc: 0.9225
# Epoch 246/300
# 400/400 [==============================] - 1s - loss: 0.2088 - acc: 0.9225
# Epoch 247/300
# 400/400 [==============================] - 1s - loss: 0.2139 - acc: 0.9200
# Epoch 248/300
# 400/400 [==============================] - 1s - loss: 0.2072 - acc: 0.9150
# Epoch 249/300
# 400/400 [==============================] - 1s - loss: 0.2418 - acc: 0.9150
# Epoch 250/300
# 400/400 [==============================] - 1s - loss: 0.2187 - acc: 0.9000
# Epoch 251/300
# 400/400 [==============================] - 1s - loss: 0.1894 - acc: 0.9225
# Epoch 252/300
# 400/400 [==============================] - 1s - loss: 0.1934 - acc: 0.9200
# Epoch 253/300
# 400/400 [==============================] - 1s - loss: 0.2192 - acc: 0.8975
# Epoch 254/300
# 400/400 [==============================] - 1s - loss: 0.1859 - acc: 0.9200
# Epoch 255/300
# 400/400 [==============================] - 1s - loss: 0.1837 - acc: 0.9250
# Epoch 256/300
# 400/400 [==============================] - 1s - loss: 0.3561 - acc: 0.8925
# Epoch 257/300
# 400/400 [==============================] - 1s - loss: 0.2468 - acc: 0.9100
# Epoch 258/300
# 400/400 [==============================] - 1s - loss: 0.2016 - acc: 0.9125
# Epoch 259/300
# 400/400 [==============================] - 1s - loss: 0.1954 - acc: 0.9200
# Epoch 260/300
# 400/400 [==============================] - 1s - loss: 0.1924 - acc: 0.9125
# Epoch 261/300
# 400/400 [==============================] - 1s - loss: 0.2048 - acc: 0.9050
# Epoch 262/300
# 400/400 [==============================] - 1s - loss: 0.2150 - acc: 0.9100
# Epoch 263/300
# 400/400 [==============================] - 1s - loss: 0.1842 - acc: 0.9225
# Epoch 264/300
# 400/400 [==============================] - 1s - loss: 0.1951 - acc: 0.9175
# Epoch 265/300
# 400/400 [==============================] - 1s - loss: 0.1937 - acc: 0.9175
# Epoch 266/300
# 400/400 [==============================] - 1s - loss: 0.2220 - acc: 0.9225
# Epoch 267/300
# 400/400 [==============================] - 1s - loss: 0.1767 - acc: 0.9275
# Epoch 268/300
# 400/400 [==============================] - 1s - loss: 0.1877 - acc: 0.9250
# Epoch 269/300
# 400/400 [==============================] - 1s - loss: 0.2365 - acc: 0.9175
# Epoch 270/300
# 400/400 [==============================] - 1s - loss: 0.1549 - acc: 0.9325
# Epoch 271/300
# 400/400 [==============================] - 1s - loss: 0.1940 - acc: 0.9075
# Epoch 272/300
# 400/400 [==============================] - 1s - loss: 0.1712 - acc: 0.9250
# Epoch 273/300
# 400/400 [==============================] - 1s - loss: 0.1694 - acc: 0.9475
# Epoch 274/300
# 400/400 [==============================] - 1s - loss: 0.2530 - acc: 0.8975
# Epoch 275/300
# 400/400 [==============================] - 1s - loss: 0.1597 - acc: 0.9425
# Epoch 276/300
# 400/400 [==============================] - 1s - loss: 0.1767 - acc: 0.9225
# Epoch 277/300
# 400/400 [==============================] - 1s - loss: 0.1598 - acc: 0.9250
# Epoch 278/300
# 400/400 [==============================] - 1s - loss: 0.2025 - acc: 0.9250
# Epoch 279/300
# 400/400 [==============================] - 1s - loss: 0.2520 - acc: 0.9125
# Epoch 280/300
# 400/400 [==============================] - 1s - loss: 0.2126 - acc: 0.9025
# Epoch 281/300
# 400/400 [==============================] - 1s - loss: 0.2336 - acc: 0.9075
# Epoch 282/300
# 400/400 [==============================] - 1s - loss: 0.1584 - acc: 0.9275
# Epoch 283/300
# 400/400 [==============================] - 1s - loss: 0.2038 - acc: 0.9100
# Epoch 284/300
# 400/400 [==============================] - 1s - loss: 0.1567 - acc: 0.9325
# Epoch 285/300
# 400/400 [==============================] - 1s - loss: 0.2396 - acc: 0.9275
# Epoch 286/300
# 400/400 [==============================] - 1s - loss: 0.1976 - acc: 0.9275
# Epoch 287/300
# 400/400 [==============================] - 1s - loss: 0.1648 - acc: 0.9400
# Epoch 288/300
# 400/400 [==============================] - 1s - loss: 0.1622 - acc: 0.9275
# Epoch 289/300
# 400/400 [==============================] - 1s - loss: 0.3150 - acc: 0.9075
# Epoch 290/300
# 400/400 [==============================] - 1s - loss: 0.1825 - acc: 0.9275
# Epoch 291/300
# 400/400 [==============================] - 1s - loss: 0.2460 - acc: 0.9075
# Epoch 292/300
# 400/400 [==============================] - 1s - loss: 0.2001 - acc: 0.9125
# Epoch 293/300
# 400/400 [==============================] - 1s - loss: 0.1582 - acc: 0.9375
# Epoch 294/300
# 400/400 [==============================] - 1s - loss: 0.1833 - acc: 0.9250
# Epoch 295/300
# 400/400 [==============================] - 1s - loss: 0.1698 - acc: 0.9325
# Epoch 296/300
# 400/400 [==============================] - 1s - loss: 0.1829 - acc: 0.9275
# Epoch 297/300
# 400/400 [==============================] - 1s - loss: 0.1583 - acc: 0.9325
# Epoch 298/300
# 400/400 [==============================] - 1s - loss: 0.2300 - acc: 0.9150
# Epoch 299/300
# 400/400 [==============================] - 1s - loss: 0.1687 - acc: 0.9275
# Epoch 300/300
# 400/400 [==============================] - 1s - loss: 0.1573 - acc: 0.9425

# %%
model.save_weights("saved_models/weights.best.dogs_vs_humans.hdf5")
humans_X_test = humans_X[100:200]
dogs_X_test = dogs_X[100:200]

my_X_test = np.concatenate((humans_X_test, dogs_X_test), axis=0)

my_predictions = [np.argmax(model.predict(np.expand_dims(t, axis=0))) for t in my_X_test]

dvh_test = []
for i in range(0, 100):
    dvh_test.append(0)

for i in range(0, 100):
    dvh_test.append(1)

# report test accuracy
my_test_accuracy = 100*np.sum(np.array(my_predictions)==np.array(dvh_test))/len(my_predictions)
print('Test accuracy: %.4f%%' % my_test_accuracy)
# Out:
# Test accuracy: 92.5000%

# %% [markdown]
# ---
# <a id='step2'></a>
#
# ## 步骤 2: 检测狗狗
#
# 在这个部分中，我们使用预训练的 [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) 模型去检测图像中的狗。下方的第一行代码就是下载了 ResNet-50 模型的网络结构参数，以及基于 [ImageNet](http://www.image-net.org/) 数据集的预训练权重。
#
# ImageNet 这目前一个非常流行的数据集，常被用来测试图像分类等计算机视觉任务相关的算法。它包含超过一千万个 URL，每一个都链接到 [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a) 中所对应的一个物体的图像。任给输入一个图像，该 ResNet-50 模型会返回一个对图像中物体的预测结果。

# %%
from keras.applications.resnet50 import ResNet50

# 定义ResNet50模型
ResNet50_model = ResNet50(weights='imagenet')

# %% [markdown]
# ### 数据预处理
#
# - 在使用 TensorFlow 作为后端的时候，在 Keras 中，CNN 的输入是一个4维数组（也被称作4维张量），它的各维度尺寸为 `(nb_samples, rows, columns, channels)`。其中 `nb_samples` 表示图像（或者样本）的总数，`rows`, `columns`, 和 `channels` 分别表示图像的行数、列数和通道数。
#
#
# - 下方的 `path_to_tensor` 函数实现如下将彩色图像的字符串型的文件路径作为输入，返回一个4维张量，作为 Keras CNN 输入。因为我们的输入图像是彩色图像，因此它们具有三个通道（ `channels` 为 `3`）。
#     1. 该函数首先读取一张图像，然后将其缩放为 224×224 的图像。
#     2. 随后，该图像被调整为具有4个维度的张量。
#     3. 对于任一输入图像，最后返回的张量的维度是：`(1, 224, 224, 3)`。
#
#
# - `paths_to_tensor` 函数将图像路径的字符串组成的 numpy 数组作为输入，并返回一个4维张量，各维度尺寸为 `(nb_samples, 224, 224, 3)`。 在这里，`nb_samples`是提供的图像路径的数据中的样本数量或图像数量。你也可以将 `nb_samples` 理解为数据集中3维张量的个数（每个3维张量表示一个不同的图像。

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # 用PIL加载RGB图像为PIL.Image.Image类型
    img = image.load_img(img_path, target_size=(224, 224))
    # 将PIL.Image.Image类型转化为格式为(224, 224, 3)的3维张量
    x = image.img_to_array(img)
    # 将3维张量转化为格式为(1, 224, 224, 3)的4维张量并返回
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### 基于 ResNet-50 架构进行预测
#
# 对于通过上述步骤得到的四维张量，在把它们输入到 ResNet-50 网络、或 Keras 中其他类似的预训练模型之前，还需要进行一些额外的处理：
# 1. 首先，这些图像的通道顺序为 RGB，我们需要重排他们的通道顺序为 BGR。
# 2. 其次，预训练模型的输入都进行了额外的归一化过程。因此我们在这里也要对这些张量进行归一化，即对所有图像所有像素都减去像素均值 `[103.939, 116.779, 123.68]`（以 RGB 模式表示，根据所有的 ImageNet 图像算出）。
#
# 导入的 `preprocess_input` 函数实现了这些功能。如果你对此很感兴趣，可以在 [这里](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py) 查看 `preprocess_input`的代码。
#
#
# 在实现了图像处理的部分之后，我们就可以使用模型来进行预测。这一步通过 `predict` 方法来实现，它返回一个向量，向量的第 i 个元素表示该图像属于第 i 个 ImageNet 类别的概率。这通过如下的 `ResNet50_predict_labels` 函数实现。
#
# 通过对预测出的向量取用 argmax 函数（找到有最大概率值的下标序号），我们可以得到一个整数，即模型预测到的物体的类别。进而根据这个 [清单](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a)，我们能够知道这具体是哪个品种的狗狗。

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions
def ResNet50_predict_labels(img_path):
    # 返回img_path路径的图像的预测向量
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### 完成狗检测模型
#
#
# 在研究该 [清单](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a) 的时候，你会注意到，狗类别对应的序号为151-268。因此，在检查预训练模型判断图像是否包含狗的时候，我们只需要检查如上的 `ResNet50_predict_labels` 函数是否返回一个介于151和268之间（包含区间端点）的值。
#
# 我们通过这些想法来完成下方的 `dog_detector` 函数，如果从图像中检测到狗就返回 `True`，否则返回 `False`。

# %%
def dog_detector(img_path):
    prediction_dog = ResNet50_predict_labels(img_path)
    return ((prediction_dog <= 268) & (prediction_dog >= 151))

# %% [markdown]
# ### 【作业】评估狗狗检测模型
#
# ---
#
# <a id='question3'></a>
# ### __问题 3:__
#
# 在下方的代码块中，使用 `dog_detector` 函数，计算：
#
# - `human_files_short`中图像检测到狗狗的百分比？
# - `dog_files_short`中图像检测到狗狗的百分比？

# %%
### TODO: 测试dog_detector函数在human_files_short和dog_files_short的表现
human_pc = len([h for h in human_files_short if dog_detector(h)])
dog_pc = len([d for d in dog_files_short if dog_detector(d)])
print("Humans: {}%, dogs: {}%".format(human_pc * 1., dog_pc * 1.))
# Out:
# Humans: 0.0%, dogs: 100.0%

# %% [markdown]
# ---
#
# <a id='step3'></a>
#
# ## 步骤 3: 从头开始创建一个CNN来分类狗品种
#
#
# 现在我们已经实现了一个函数，能够在图像中识别人类及狗狗。但我们需要更进一步的方法，来对狗的类别进行识别。在这一步中，你需要实现一个卷积神经网络来对狗的品种进行分类。你需要__从头实现__你的卷积神经网络（在这一阶段，你还不能使用迁移学习），并且你需要达到超过1%的测试集准确率。在本项目的步骤五种，你还有机会使用迁移学习来实现一个准确率大大提高的模型。
#
# 在添加卷积层的时候，注意不要加上太多的（可训练的）层。更多的参数意味着更长的训练时间，也就是说你更可能需要一个 GPU 来加速训练过程。万幸的是，Keras 提供了能够轻松预测每次迭代（epoch）花费时间所需的函数。你可以据此推断你算法所需的训练时间。
#
# 值得注意的是，对狗的图像进行分类是一项极具挑战性的任务。因为即便是一个正常人，也很难区分布列塔尼犬和威尔士史宾格犬。
#
#
# 布列塔尼犬（Brittany） | 威尔士史宾格犬（Welsh Springer Spaniel）
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# 不难发现其他的狗品种会有很小的类间差别（比如金毛寻回犬和美国水猎犬）。
#
#
# 金毛寻回犬（Curly-Coated Retriever） | 美国水猎犬（American Water Spaniel）
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
# 同样，拉布拉多犬（labradors）有黄色、棕色和黑色这三种。那么你设计的基于视觉的算法将不得不克服这种较高的类间差别，以达到能够将这些不同颜色的同类狗分到同一个品种中。
#
# 黄色拉布拉多犬（Yellow Labrador） | 棕色拉布拉多犬（Chocolate Labrador） | 黑色拉布拉多犬（Black Labrador）
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# 我们也提到了随机分类将得到一个非常低的结果：不考虑品种略有失衡的影响，随机猜测到正确品种的概率是1/133，相对应的准确率是低于1%的。
#
# 请记住，在深度学习领域，实践远远高于理论。大量尝试不同的框架吧，相信你的直觉！当然，玩得开心！
#
#
# ### 数据预处理
#
#
# 通过对每张图像的像素值除以255，我们对图像实现了归一化处理。

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# Keras中的数据预处理过程
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 6680/6680 [00:53<00:00, 124.70it/s]
# 100%|██████████| 835/835 [00:06<00:00, 136.36it/s]
# 100%|██████████| 836/836 [00:06<00:00, 137.47it/s]

# %% [markdown]
# ### 【练习】模型架构
#
#
# 创建一个卷积神经网络来对狗品种进行分类。在你代码块的最后，执行 `model.summary()` 来输出你模型的总结信息。
#
# 我们已经帮你导入了一些所需的 Python 库，如有需要你可以自行导入。如果你在过程中遇到了困难，如下是给你的一点小提示——该模型能够在5个 epoch 内取得超过1%的测试准确率，并且能在CPU上很快地训练。
#
# ![Sample CNN](images/sample_cnn.png)

# %% [markdown]
# ---
#
# <a id='question4'></a>
#
# ### __问题 4:__
#
# 在下方的代码块中尝试使用 Keras 搭建卷积网络的架构，并回答相关的问题。
#
# 1. 你可以尝试自己搭建一个卷积网络的模型，那么你需要回答你搭建卷积网络的具体步骤（用了哪些层）以及为什么这样搭建。
# 2. 你也可以根据上图提示的步骤搭建卷积网络，那么请说明为何如上的架构能够在该问题上取得很好的表现。
#
# __回答:__

# %% [markdown]
# Flattening通过GlobalAveragePooling发生，我发现它比简单的Flatten（）更有效。在前两个ConV层，我增加了过滤器，但是我减小了内核大小。
# 然后我将来自GAP的值送入两个连续的FC层。这使我能够使用至少一个“relu”激活层在FC层，这样做会非常有效。

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

model = Sequential()

### TODO: 定义你的网络架构
model.add(Conv2D(filters=32, kernel_size=(8,8), input_shape=(224, 224, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2), padding='same'))
model.add(Conv2D(filters=64, kernel_size=(7,7)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(1,1), padding='same'))
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.1))
model.add(Dense(500))
model.add(Activation("relu"))
model.add(Dense(133))
model.add(Activation("softmax"))                 
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 217, 217, 32)      6176
# _________________________________________________________________
# activation_54 (Activation)   (None, 217, 217, 32)      0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 109, 109, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 103, 103, 64)      100416
# _________________________________________________________________
# activation_55 (Activation)   (None, 103, 103, 64)      0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 103, 103, 64)      0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 64)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 500)               32500
# _________________________________________________________________
# activation_56 (Activation)   (None, 500)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 133)               66633
# _________________________________________________________________
# activation_57 (Activation)   (None, 133)               0
# =================================================================
# Total params: 205,725.0
# Trainable params: 205,725.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %%
## 编译模型
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ---

# %% [markdown]
# ## 【练习】训练模型
#
#
# ---
#
# <a id='question5'></a>
#
# ### __问题 5:__
#
# 在下方代码单元训练模型。使用模型检查点（model checkpointing）来储存具有最低验证集 loss 的模型。
#
# 可选题：你也可以对训练集进行 [数据增强](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html)，来优化模型的表现。

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: 设置训练模型的epochs的数量

epochs = 10

### 不要修改下方代码

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/10
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.3693 - acc: 0.0511Epoch 00000: val_loss improved from inf to 4.37774, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 42s - loss: 4.3694 - acc: 0.0510 - val_loss: 4.3777 - val_acc: 0.0551
# Epoch 2/10
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.3117 - acc: 0.0604Epoch 00001: val_loss improved from 4.37774 to 4.31600, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 42s - loss: 4.3112 - acc: 0.0603 - val_loss: 4.3160 - val_acc: 0.0563
# Epoch 3/10
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.2470 - acc: 0.0680Epoch 00002: val_loss did not improve
# 6680/6680 [==============================] - 42s - loss: 4.2459 - acc: 0.0684 - val_loss: 4.3189 - val_acc: 0.0635
# Epoch 4/10
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.1796 - acc: 0.0757Epoch 00003: val_loss improved from 4.31600 to 4.26551, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 42s - loss: 4.1802 - acc: 0.0757 - val_loss: 4.2655 - val_acc: 0.0707
# Epoch 5/10
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.1292 - acc: 0.0833Epoch 00004: val_loss improved from 4.26551 to 4.18666, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 42s - loss: 4.1282 - acc: 0.0834 - val_loss: 4.1867 - val_acc: 0.0802
# Epoch 6/10
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.0864 - acc: 0.0853Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 42s - loss: 4.0875 - acc: 0.0852 - val_loss: 4.3590 - val_acc: 0.0635
# Epoch 7/10
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.0471 - acc: 0.0943Epoch 00006: val_loss improved from 4.18666 to 4.08485, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 42s - loss: 4.0474 - acc: 0.0943 - val_loss: 4.0849 - val_acc: 0.0946
# Epoch 8/10
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.9923 - acc: 0.0955Epoch 00007: val_loss did not improve
# 6680/6680 [==============================] - 42s - loss: 3.9919 - acc: 0.0955 - val_loss: 4.3891 - val_acc: 0.0707
# Epoch 9/10
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.9585 - acc: 0.1033Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 42s - loss: 3.9582 - acc: 0.1033 - val_loss: 4.0867 - val_acc: 0.0838
# Epoch 10/10
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.9163 - acc: 0.1044Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 42s - loss: 3.9158 - acc: 0.1043 - val_loss: 4.2066 - val_acc: 0.0778

# %%
## 加载具有最好验证loss的模型

model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %% [markdown]
# ### 测试模型
#
# 在狗图像的测试数据集上试用你的模型。确保测试准确率大于1%。

# %%
# 获取测试数据集中每一个图像所预测的狗品种的index
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# 报告测试准确率
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 8.9713%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## 步骤 4: 使用一个CNN来区分狗的品种
#
#
# 使用 迁移学习（Transfer Learning）的方法，能帮助我们在不损失准确率的情况下大大减少训练时间。在以下步骤中，你可以尝试使用迁移学习来训练你自己的CNN。

# %% [markdown]
# ### 得到从图像中提取的特征向量（Bottleneck Features）

# %%
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### 模型架构
#
# 该模型使用预训练的 VGG-16 模型作为固定的图像特征提取器，其中 VGG-16 最后一层卷积层的输出被直接输入到我们的模型。我们只需要添加一个全局平均池化层以及一个全连接层，其中全连接层使用 softmax 激活函数，对每一个狗的种类都包含一个节点。

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_3 ( (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229.0
# Trainable params: 68,229.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %%
## 编译模型

VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
## 训练模型

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=100, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/100
# 6480/6680 [============================>.] - ETA: 0s - loss: 12.1900 - acc: 0.1224Epoch 00000: val_loss improved from inf to 10.62806, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 12.1298 - acc: 0.1251 - val_loss: 10.6281 - val_acc: 0.2240
# Epoch 2/100
# 6500/6680 [============================>.] - ETA: 0s - loss: 9.5896 - acc: 0.2968Epoch 00001: val_loss improved from 10.62806 to 9.37299, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 9.5956 - acc: 0.2972 - val_loss: 9.3730 - val_acc: 0.2958
# Epoch 3/100
# 6560/6680 [============================>.] - ETA: 0s - loss: 8.8907 - acc: 0.3782Epoch 00002: val_loss improved from 9.37299 to 9.16451, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.8764 - acc: 0.3790 - val_loss: 9.1645 - val_acc: 0.3377
# Epoch 4/100
# 6460/6680 [============================>.] - ETA: 0s - loss: 8.6883 - acc: 0.4149Epoch 00003: val_loss improved from 9.16451 to 9.10400, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.6643 - acc: 0.4157 - val_loss: 9.1040 - val_acc: 0.3473
# Epoch 5/100
# 6540/6680 [============================>.] - ETA: 0s - loss: 8.4970 - acc: 0.4323Epoch 00004: val_loss improved from 9.10400 to 8.95840, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.4843 - acc: 0.4329 - val_loss: 8.9584 - val_acc: 0.3665
# Epoch 6/100
# 6480/6680 [============================>.] - ETA: 0s - loss: 8.2446 - acc: 0.4515Epoch 00005: val_loss improved from 8.95840 to 8.70915, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.2252 - acc: 0.4527 - val_loss: 8.7091 - val_acc: 0.3820
# Epoch 7/100
# 6460/6680 [============================>.] - ETA: 0s - loss: 7.9974 - acc: 0.4715Epoch 00006: val_loss improved from 8.70915 to 8.52936, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.0055 - acc: 0.4713 - val_loss: 8.5294 - val_acc: 0.3856
# Epoch 8/100
# 6500/6680 [============================>.] - ETA: 0s - loss: 7.8761 - acc: 0.4865Epoch 00007: val_loss improved from 8.52936 to 8.44715, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 7.8847 - acc: 0.4861 - val_loss: 8.4472 - val_acc: 0.4024
# Epoch 9/100
# 6520/6680 [============================>.] - ETA: 0s - loss: 7.8313 - acc: 0.4972Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 7.8517 - acc: 0.4958 - val_loss: 8.4779 - val_acc: 0.3916
# Epoch 10/100
# 6560/6680 [============================>.] - ETA: 0s - loss: 7.7895 - acc: 0.4992Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 7.7887 - acc: 0.4993 - val_loss: 8.5002 - val_acc: 0.4000
# Epoch 11/100
# 6440/6680 [===========================>..] - ETA: 0s - loss: 7.7111 - acc: 0.5075Epoch 00010: val_loss improved from 8.44715 to 8.28099, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 7.6802 - acc: 0.5096 - val_loss: 8.2810 - val_acc: 0.4156
# Epoch 12/100
# 6460/6680 [============================>.] - ETA: 0s - loss: 7.5580 - acc: 0.5163Epoch 00011: val_loss improved from 8.28099 to 8.24454, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 7.5466 - acc: 0.5172 - val_loss: 8.2445 - val_acc: 0.4144
# Epoch 13/100
# 6480/6680 [============================>.] - ETA: 0s - loss: 7.4328 - acc: 0.5273Epoch 00012: val_loss improved from 8.24454 to 8.13815, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 7.4469 - acc: 0.5266 - val_loss: 8.1381 - val_acc: 0.4180
# Epoch 14/100
# 6560/6680 [============================>.] - ETA: 0s - loss: 7.3090 - acc: 0.5325Epoch 00013: val_loss improved from 8.13815 to 8.02544, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 7.3292 - acc: 0.5310 - val_loss: 8.0254 - val_acc: 0.4240
# Epoch 15/100
# 6500/6680 [============================>.] - ETA: 0s - loss: 7.1128 - acc: 0.5451Epoch 00014: val_loss improved from 8.02544 to 7.93770, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 7.1367 - acc: 0.5436 - val_loss: 7.9377 - val_acc: 0.4443
# Epoch 16/100
# 6480/6680 [============================>.] - ETA: 0s - loss: 7.0809 - acc: 0.5523Epoch 00015: val_loss improved from 7.93770 to 7.87234, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 7.0794 - acc: 0.5524 - val_loss: 7.8723 - val_acc: 0.4419
# Epoch 17/100
# 6440/6680 [===========================>..] - ETA: 0s - loss: 7.0740 - acc: 0.5547Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 7.0622 - acc: 0.5554 - val_loss: 7.8771 - val_acc: 0.4515
# Epoch 18/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 7.0562 - acc: 0.5574Epoch 00017: val_loss improved from 7.87234 to 7.80772, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 7.0496 - acc: 0.5578 - val_loss: 7.8077 - val_acc: 0.4587
# Epoch 19/100
# 6480/6680 [============================>.] - ETA: 0s - loss: 7.0389 - acc: 0.5596Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 7.0399 - acc: 0.5594 - val_loss: 7.9289 - val_acc: 0.4551
# Epoch 20/100
# 6520/6680 [============================>.] - ETA: 0s - loss: 6.9523 - acc: 0.5610Epoch 00019: val_loss improved from 7.80772 to 7.75850, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 6.9482 - acc: 0.5608 - val_loss: 7.7585 - val_acc: 0.4563
# Epoch 21/100
# 6620/6680 [============================>.] - ETA: 0s - loss: 6.8522 - acc: 0.5672Epoch 00020: val_loss improved from 7.75850 to 7.73319, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 6.8427 - acc: 0.5678 - val_loss: 7.7332 - val_acc: 0.4467
# Epoch 22/100
# 6460/6680 [============================>.] - ETA: 0s - loss: 6.7249 - acc: 0.5712Epoch 00021: val_loss improved from 7.73319 to 7.64365, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 6.7003 - acc: 0.5723 - val_loss: 7.6436 - val_acc: 0.4611
# Epoch 23/100
# 6540/6680 [============================>.] - ETA: 0s - loss: 6.6334 - acc: 0.5797Epoch 00022: val_loss improved from 7.64365 to 7.58695, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 6.6342 - acc: 0.5798 - val_loss: 7.5870 - val_acc: 0.4611
# Epoch 24/100
# 6500/6680 [============================>.] - ETA: 0s - loss: 6.5903 - acc: 0.5815Epoch 00023: val_loss improved from 7.58695 to 7.49061, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 6.5712 - acc: 0.5825 - val_loss: 7.4906 - val_acc: 0.4719
# Epoch 25/100
# 6500/6680 [============================>.] - ETA: 0s - loss: 6.5264 - acc: 0.5886Epoch 00024: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 6.5202 - acc: 0.5889 - val_loss: 7.5401 - val_acc: 0.4635
# Epoch 26/100
# 6440/6680 [===========================>..] - ETA: 0s - loss: 6.4513 - acc: 0.5899Epoch 00025: val_loss improved from 7.49061 to 7.38195, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 6.4441 - acc: 0.5904 - val_loss: 7.3820 - val_acc: 0.4623
# Epoch 27/100
# 6560/6680 [============================>.] - ETA: 0s - loss: 6.3297 - acc: 0.5976Epoch 00026: val_loss improved from 7.38195 to 7.27371, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 6.3270 - acc: 0.5978 - val_loss: 7.2737 - val_acc: 0.4814
# Epoch 28/100
# 6480/6680 [============================>.] - ETA: 0s - loss: 6.2180 - acc: 0.5972Epoch 00027: val_loss improved from 7.27371 to 7.21833, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 6.1967 - acc: 0.5985 - val_loss: 7.2183 - val_acc: 0.4814
# Epoch 29/100
# 6540/6680 [============================>.] - ETA: 0s - loss: 6.0403 - acc: 0.6107Epoch 00028: val_loss improved from 7.21833 to 7.17449, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 6.0255 - acc: 0.6115 - val_loss: 7.1745 - val_acc: 0.4766
# Epoch 30/100
# 6460/6680 [============================>.] - ETA: 0s - loss: 5.9833 - acc: 0.6193Epoch 00029: val_loss improved from 7.17449 to 7.11249, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 5.9566 - acc: 0.6210 - val_loss: 7.1125 - val_acc: 0.4874
# Epoch 31/100
# 6440/6680 [===========================>..] - ETA: 0s - loss: 5.9109 - acc: 0.6256Epoch 00030: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.9363 - acc: 0.6240 - val_loss: 7.1778 - val_acc: 0.4874
# Epoch 32/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 5.9198 - acc: 0.6279Epoch 00031: val_loss improved from 7.11249 to 7.09387, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 5.9238 - acc: 0.6277 - val_loss: 7.0939 - val_acc: 0.4862
# Epoch 33/100
# 6600/6680 [============================>.] - ETA: 0s - loss: 5.9249 - acc: 0.6285Epoch 00032: val_loss improved from 7.09387 to 7.03901, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 5.9167 - acc: 0.6290 - val_loss: 7.0390 - val_acc: 0.4934
# Epoch 34/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 5.9025 - acc: 0.6318Epoch 00033: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.9089 - acc: 0.6314 - val_loss: 7.0687 - val_acc: 0.4958
# Epoch 35/100
# 6500/6680 [============================>.] - ETA: 0s - loss: 5.9314 - acc: 0.6297Epoch 00034: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.9043 - acc: 0.6314 - val_loss: 7.0614 - val_acc: 0.4982
# Epoch 36/100
# 6480/6680 [============================>.] - ETA: 0s - loss: 5.8952 - acc: 0.6321Epoch 00035: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.9055 - acc: 0.6314 - val_loss: 7.0733 - val_acc: 0.4946
# Epoch 37/100
# 6640/6680 [============================>.] - ETA: 0s - loss: 5.9026 - acc: 0.6325Epoch 00036: val_loss improved from 7.03901 to 7.01608, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 5.8987 - acc: 0.6328 - val_loss: 7.0161 - val_acc: 0.5054
# Epoch 38/100
# 6640/6680 [============================>.] - ETA: 0s - loss: 5.9010 - acc: 0.6331Epoch 00037: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.8995 - acc: 0.6332 - val_loss: 7.0613 - val_acc: 0.4946
# Epoch 39/100
# 6480/6680 [============================>.] - ETA: 0s - loss: 5.8814 - acc: 0.6338Epoch 00038: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.8983 - acc: 0.6328 - val_loss: 7.0555 - val_acc: 0.5006
# Epoch 40/100
# 6500/6680 [============================>.] - ETA: 0s - loss: 5.8638 - acc: 0.6351Epoch 00039: val_loss improved from 7.01608 to 7.01507, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 5.8940 - acc: 0.6332 - val_loss: 7.0151 - val_acc: 0.5078
# Epoch 41/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 5.8410 - acc: 0.6336Epoch 00040: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.8452 - acc: 0.6334 - val_loss: 7.0373 - val_acc: 0.5006
# Epoch 42/100
# 6600/6680 [============================>.] - ETA: 0s - loss: 5.8091 - acc: 0.6347Epoch 00041: val_loss improved from 7.01507 to 6.94555, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 5.8280 - acc: 0.6334 - val_loss: 6.9455 - val_acc: 0.5054
# Epoch 43/100
# 6560/6680 [============================>.] - ETA: 0s - loss: 5.7585 - acc: 0.6364Epoch 00042: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.7881 - acc: 0.6346 - val_loss: 7.1030 - val_acc: 0.4946
# Epoch 44/100
# 6560/6680 [============================>.] - ETA: 0s - loss: 5.7538 - acc: 0.6380Epoch 00043: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.7544 - acc: 0.6379 - val_loss: 7.0334 - val_acc: 0.4958
# Epoch 45/100
# 6460/6680 [============================>.] - ETA: 0s - loss: 5.7722 - acc: 0.6367Epoch 00044: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.7295 - acc: 0.6394 - val_loss: 7.0669 - val_acc: 0.4970
# Epoch 46/100
# 6500/6680 [============================>.] - ETA: 0s - loss: 5.6697 - acc: 0.6418Epoch 00045: val_loss improved from 6.94555 to 6.92883, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 5.6843 - acc: 0.6409 - val_loss: 6.9288 - val_acc: 0.4994
# Epoch 47/100
# 6460/6680 [============================>.] - ETA: 0s - loss: 5.6325 - acc: 0.6432Epoch 00046: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.6283 - acc: 0.6436 - val_loss: 6.9677 - val_acc: 0.5078
# Epoch 48/100
# 6520/6680 [============================>.] - ETA: 0s - loss: 5.5676 - acc: 0.6491Epoch 00047: val_loss improved from 6.92883 to 6.83999, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 5.5901 - acc: 0.6476 - val_loss: 6.8400 - val_acc: 0.5114
# Epoch 49/100
# 6440/6680 [===========================>..] - ETA: 0s - loss: 5.5677 - acc: 0.6506Epoch 00048: val_loss improved from 6.83999 to 6.83948, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 5.5760 - acc: 0.6500 - val_loss: 6.8395 - val_acc: 0.5054
# Epoch 50/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 5.5645 - acc: 0.6518Epoch 00049: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.5623 - acc: 0.6519 - val_loss: 6.8757 - val_acc: 0.5042
# Epoch 51/100
# 6640/6680 [============================>.] - ETA: 0s - loss: 5.5474 - acc: 0.6538Epoch 00050: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.5528 - acc: 0.6534 - val_loss: 6.9180 - val_acc: 0.5102
# Epoch 52/100
# 6420/6680 [===========================>..] - ETA: 0s - loss: 5.5373 - acc: 0.6544Epoch 00051: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.5494 - acc: 0.6536 - val_loss: 6.9074 - val_acc: 0.5018
# Epoch 53/100
# 6440/6680 [===========================>..] - ETA: 0s - loss: 5.5316 - acc: 0.6531Epoch 00052: val_loss improved from 6.83948 to 6.83884, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 5.5256 - acc: 0.6534 - val_loss: 6.8388 - val_acc: 0.5102
# Epoch 54/100
# 6480/6680 [============================>.] - ETA: 0s - loss: 5.5084 - acc: 0.6545Epoch 00053: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.4979 - acc: 0.6552 - val_loss: 6.9074 - val_acc: 0.4970
# Epoch 55/100
# 6600/6680 [============================>.] - ETA: 0s - loss: 5.4697 - acc: 0.6576Epoch 00054: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.4887 - acc: 0.6564 - val_loss: 6.8522 - val_acc: 0.5114
# Epoch 56/100
# 6440/6680 [===========================>..] - ETA: 0s - loss: 5.4586 - acc: 0.6589Epoch 00055: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.4792 - acc: 0.6576 - val_loss: 6.8887 - val_acc: 0.4910
# Epoch 57/100
# 6500/6680 [============================>.] - ETA: 0s - loss: 5.2315 - acc: 0.6600Epoch 00056: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.2461 - acc: 0.6591 - val_loss: 6.8967 - val_acc: 0.4838
# Epoch 58/100
# 6540/6680 [============================>.] - ETA: 0s - loss: 5.0725 - acc: 0.6752Epoch 00057: val_loss improved from 6.83884 to 6.60712, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 5.0762 - acc: 0.6749 - val_loss: 6.6071 - val_acc: 0.5150
# Epoch 59/100
# 6460/6680 [============================>.] - ETA: 0s - loss: 5.0100 - acc: 0.6833Epoch 00058: val_loss improved from 6.60712 to 6.57688, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 5.0292 - acc: 0.6820 - val_loss: 6.5769 - val_acc: 0.5090
# Epoch 60/100
# 6500/6680 [============================>.] - ETA: 0s - loss: 5.0392 - acc: 0.6834Epoch 00059: val_loss improved from 6.57688 to 6.50471, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 5.0176 - acc: 0.6846 - val_loss: 6.5047 - val_acc: 0.5293
# Epoch 61/100
# 6520/6680 [============================>.] - ETA: 0s - loss: 5.0222 - acc: 0.6848Epoch 00060: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 5.0105 - acc: 0.6856 - val_loss: 6.5270 - val_acc: 0.5222
# Epoch 62/100
# 6640/6680 [============================>.] - ETA: 0s - loss: 5.0147 - acc: 0.6860Epoch 00061: val_loss improved from 6.50471 to 6.45136, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 5.0041 - acc: 0.6867 - val_loss: 6.4514 - val_acc: 0.5257
# Epoch 63/100
# 6640/6680 [============================>.] - ETA: 0s - loss: 4.9146 - acc: 0.6883Epoch 00062: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.9189 - acc: 0.6880 - val_loss: 6.4962 - val_acc: 0.5210
# Epoch 64/100
# 6620/6680 [============================>.] - ETA: 0s - loss: 4.8645 - acc: 0.6935Epoch 00063: val_loss improved from 6.45136 to 6.31208, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 4.8701 - acc: 0.6931 - val_loss: 6.3121 - val_acc: 0.5341
# Epoch 65/100
# 6640/6680 [============================>.] - ETA: 0s - loss: 4.8446 - acc: 0.6952Epoch 00064: val_loss improved from 6.31208 to 6.29304, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 4.8590 - acc: 0.6943 - val_loss: 6.2930 - val_acc: 0.5365
# Epoch 66/100
# 6440/6680 [===========================>..] - ETA: 0s - loss: 4.8392 - acc: 0.6972Epoch 00065: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.8497 - acc: 0.6964 - val_loss: 6.4509 - val_acc: 0.5257
# Epoch 67/100
# 6540/6680 [============================>.] - ETA: 0s - loss: 4.8220 - acc: 0.6957Epoch 00066: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.8218 - acc: 0.6958 - val_loss: 6.4519 - val_acc: 0.5329
# Epoch 68/100
# 6420/6680 [===========================>..] - ETA: 0s - loss: 4.7618 - acc: 0.7000Epoch 00067: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.7797 - acc: 0.6990 - val_loss: 6.3530 - val_acc: 0.5389
# Epoch 69/100
# 6460/6680 [============================>.] - ETA: 0s - loss: 4.7348 - acc: 0.7022Epoch 00068: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.7456 - acc: 0.7015 - val_loss: 6.3393 - val_acc: 0.5377
# Epoch 70/100
# 6460/6680 [============================>.] - ETA: 0s - loss: 4.7299 - acc: 0.7033Epoch 00069: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.7336 - acc: 0.7030 - val_loss: 6.2976 - val_acc: 0.5521
# Epoch 71/100
# 6540/6680 [============================>.] - ETA: 0s - loss: 4.7315 - acc: 0.7049Epoch 00070: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.7301 - acc: 0.7048 - val_loss: 6.3312 - val_acc: 0.5413
# Epoch 72/100
# 6560/6680 [============================>.] - ETA: 0s - loss: 4.7391 - acc: 0.7041Epoch 00071: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.7240 - acc: 0.7051 - val_loss: 6.3079 - val_acc: 0.5497
# Epoch 73/100
# 6640/6680 [============================>.] - ETA: 0s - loss: 4.7170 - acc: 0.7062Epoch 00072: val_loss improved from 6.29304 to 6.27861, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 4.7225 - acc: 0.7058 - val_loss: 6.2786 - val_acc: 0.5449
# Epoch 74/100
# 6620/6680 [============================>.] - ETA: 0s - loss: 4.7229 - acc: 0.7065Epoch 00073: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.7215 - acc: 0.7066 - val_loss: 6.3337 - val_acc: 0.5305
# Epoch 75/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.7272 - acc: 0.7059Epoch 00074: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.7227 - acc: 0.7061 - val_loss: 6.2791 - val_acc: 0.5377
# Epoch 76/100
# 6460/6680 [============================>.] - ETA: 0s - loss: 4.6993 - acc: 0.7076Epoch 00075: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.7212 - acc: 0.7060 - val_loss: 6.3289 - val_acc: 0.5425
# Epoch 77/100
# 6520/6680 [============================>.] - ETA: 0s - loss: 4.7125 - acc: 0.7067Epoch 00076: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.7227 - acc: 0.7061 - val_loss: 6.2812 - val_acc: 0.5401
# Epoch 78/100
# 6420/6680 [===========================>..] - ETA: 0s - loss: 4.7308 - acc: 0.7056Epoch 00077: val_loss improved from 6.27861 to 6.23036, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 4.7213 - acc: 0.7061 - val_loss: 6.2304 - val_acc: 0.5485
# Epoch 79/100
# 6440/6680 [===========================>..] - ETA: 0s - loss: 4.6997 - acc: 0.7040Epoch 00078: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.6872 - acc: 0.7049 - val_loss: 6.4648 - val_acc: 0.5305
# Epoch 80/100
# 6440/6680 [===========================>..] - ETA: 0s - loss: 4.6479 - acc: 0.7079Epoch 00079: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.6261 - acc: 0.7093 - val_loss: 6.3221 - val_acc: 0.5425
# Epoch 81/100
# 6440/6680 [===========================>..] - ETA: 0s - loss: 4.5921 - acc: 0.7123Epoch 00080: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.6089 - acc: 0.7112 - val_loss: 6.3106 - val_acc: 0.5473
# Epoch 82/100
# 6640/6680 [============================>.] - ETA: 0s - loss: 4.5897 - acc: 0.7120Epoch 00081: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.5912 - acc: 0.7120 - val_loss: 6.2899 - val_acc: 0.5437
# Epoch 83/100
# 6640/6680 [============================>.] - ETA: 0s - loss: 4.5637 - acc: 0.7133Epoch 00082: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.5654 - acc: 0.7132 - val_loss: 6.3602 - val_acc: 0.5413
# Epoch 84/100
# 6460/6680 [============================>.] - ETA: 0s - loss: 4.5354 - acc: 0.7159Epoch 00083: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.5381 - acc: 0.7157 - val_loss: 6.3069 - val_acc: 0.5401
# Epoch 85/100
# 6440/6680 [===========================>..] - ETA: 0s - loss: 4.5633 - acc: 0.7138Epoch 00084: val_loss improved from 6.23036 to 6.22050, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 4.5236 - acc: 0.7162 - val_loss: 6.2205 - val_acc: 0.5485
# Epoch 86/100
# 6420/6680 [===========================>..] - ETA: 0s - loss: 4.4932 - acc: 0.7190Epoch 00085: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.5156 - acc: 0.7177 - val_loss: 6.2697 - val_acc: 0.5533
# Epoch 87/100
# 6500/6680 [============================>.] - ETA: 0s - loss: 4.4745 - acc: 0.7209Epoch 00086: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.5102 - acc: 0.7186 - val_loss: 6.2593 - val_acc: 0.5449
# Epoch 88/100
# 6440/6680 [===========================>..] - ETA: 0s - loss: 4.4798 - acc: 0.7200Epoch 00087: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.5095 - acc: 0.7183 - val_loss: 6.2535 - val_acc: 0.5497
# Epoch 89/100
# 6600/6680 [============================>.] - ETA: 0s - loss: 4.5122 - acc: 0.7189Epoch 00088: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.5088 - acc: 0.7192 - val_loss: 6.2950 - val_acc: 0.5461
# Epoch 90/100
# 6500/6680 [============================>.] - ETA: 0s - loss: 4.4692 - acc: 0.7215Epoch 00089: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.5056 - acc: 0.7193 - val_loss: 6.2277 - val_acc: 0.5533
# Epoch 91/100
# 6500/6680 [============================>.] - ETA: 0s - loss: 4.5028 - acc: 0.7197Epoch 00090: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.5033 - acc: 0.7196 - val_loss: 6.2945 - val_acc: 0.5473
# Epoch 92/100
# 6460/6680 [============================>.] - ETA: 0s - loss: 4.4895 - acc: 0.7206Epoch 00091: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.5038 - acc: 0.7196 - val_loss: 6.2767 - val_acc: 0.5473
# Epoch 93/100
# 6600/6680 [============================>.] - ETA: 0s - loss: 4.5050 - acc: 0.7194Epoch 00092: val_loss improved from 6.22050 to 6.21466, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 4.5017 - acc: 0.7196 - val_loss: 6.2147 - val_acc: 0.5413
# Epoch 94/100
# 6480/6680 [============================>.] - ETA: 0s - loss: 4.4910 - acc: 0.7204Epoch 00093: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.4989 - acc: 0.7199 - val_loss: 6.2458 - val_acc: 0.5473
# Epoch 95/100
# 6480/6680 [============================>.] - ETA: 0s - loss: 4.4790 - acc: 0.7211Epoch 00094: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.5018 - acc: 0.7198 - val_loss: 6.2719 - val_acc: 0.5557
# Epoch 96/100
# 6460/6680 [============================>.] - ETA: 0s - loss: 4.4857 - acc: 0.7206Epoch 00095: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.4996 - acc: 0.7198 - val_loss: 6.3069 - val_acc: 0.5437
# Epoch 97/100
# 6480/6680 [============================>.] - ETA: 0s - loss: 4.4889 - acc: 0.7208Epoch 00096: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.4993 - acc: 0.7202 - val_loss: 6.2423 - val_acc: 0.5497
# Epoch 98/100
# 6500/6680 [============================>.] - ETA: 0s - loss: 4.5112 - acc: 0.7194Epoch 00097: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.4982 - acc: 0.7202 - val_loss: 6.2496 - val_acc: 0.5545
# Epoch 99/100
# 6640/6680 [============================>.] - ETA: 0s - loss: 4.5181 - acc: 0.7193Epoch 00098: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.5007 - acc: 0.7204 - val_loss: 6.2246 - val_acc: 0.5449
# Epoch 100/100
# 6460/6680 [============================>.] - ETA: 0s - loss: 4.4921 - acc: 0.7206Epoch 00099: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 4.4986 - acc: 0.7202 - val_loss: 6.2663 - val_acc: 0.5425

# %%
## 加载具有最好验证loss的模型

VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### 测试模型
# 现在，我们可以测试此CNN在狗图像测试数据集中识别品种的效果如何。我们在下方打印出测试准确率。

# %%
# 获取测试数据集中每一个图像所预测的狗品种的index
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# 报告测试准确率
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 57.0574%

# %% [markdown]
# ### 使用模型预测狗的品种

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # 提取bottleneck特征
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # 获取预测向量
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # 返回此模型预测的狗的品种
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## 步骤 5: 建立一个CNN来分类狗的品种（使用迁移学习）
#
# 现在你将使用迁移学习来建立一个CNN，从而可以从图像中识别狗的品种。你的 CNN 在测试集上的准确率必须至少达到60%。
#
# 在步骤4中，我们使用了迁移学习来创建一个使用基于 VGG-16 提取的特征向量来搭建一个 CNN。在本部分内容中，你必须使用另一个预训练模型来搭建一个 CNN。为了让这个任务更易实现，我们已经预先对目前 keras 中可用的几种网络进行了预训练：
#
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# 这些文件被命名为为：
#
#     Dog{network}Data.npz
#
# 其中 `{network}` 可以是 `VGG19`、`Resnet50`、`InceptionV3` 或 `Xception` 中的一个。选择上方网络架构中的一个，下载相对应的bottleneck特征，并将所下载的文件保存在目录 `bottleneck_features/` 中。
#
#
# ### 【练习】获取模型的特征向量
#
# 在下方代码块中，通过运行下方代码提取训练、测试与验证集相对应的bottleneck特征。
#
#     bottleneck_features = np.load('bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
### TODO: 从另一个预训练的CNN获取bottleneck特征
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_Inception = bottleneck_features['train']
valid_Inception = bottleneck_features['valid']
test_Inception = bottleneck_features['test']

# %% [markdown]
# ### 【练习】模型架构
#
# 建立一个CNN来分类狗品种。在你的代码单元块的最后，通过运行如下代码输出网络的结构：
#
#         <your model's name>.summary()
#
# ---
#
# <a id='question6'></a>
#
# ### __问题 6:__
#
#
# 在下方的代码块中尝试使用 Keras 搭建最终的网络架构，并回答你实现最终 CNN 架构的步骤与每一步的作用，并描述你在迁移学习过程中，使用该网络架构的原因。
#
#
# __回答:__

# %% [markdown]
# 我是这样设计框架的：第一个GAP层，用于从初始瓶颈特征处理的图像中提取最佳特征，然后将其送入500节点FC层，并使用激活函数“tanh”来激活，最后的133个节点使用激活函数“softmax”用于最终分类。
# 最后选择这个网络框架的原因是因为本框架具有更高的准确率。

# %%
### TODO: 定义你的框架
Inc_model = Sequential()
Inc_model.add(GlobalAveragePooling2D(input_shape=train_Inception.shape[1:]))
Inc_model.add(Dense(500))
Inc_model.add(Activation("tanh"))
Inc_model.add(Dropout(0.2))
Inc_model.add(Dense(133, activation='softmax'))
Inc_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_4 ( (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 500)               256500
# _________________________________________________________________
# activation_58 (Activation)   (None, 500)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 133)               66633
# =================================================================
# Total params: 323,133.0
# Trainable params: 323,133.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %%
### TODO: 编译模型
Inc_model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ---
#
# ### 【练习】训练模型
#
# <a id='question7'></a>
#
# ### __问题 7:__
#
# 在下方代码单元中训练你的模型。使用模型检查点（model checkpointing）来储存具有最低验证集 loss 的模型。
#
# 当然，你也可以对训练集进行 [数据增强](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html) 以优化模型的表现，不过这不是必须的步骤。

# %%
### TODO: 训练模型
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.Inc_model.hdf5', 
                               verbose=1, save_best_only=True)
Inc_model.fit(train_Inception, train_targets, 
          validation_data=(valid_Inception, valid_targets),
          epochs=500, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 2.8715 - acc: 0.3483Epoch 00000: val_loss improved from inf to 1.61444, saving model to saved_models/weights.best.Inc_model.hdf5
# 6680/6680 [==============================] - 2s - loss: 2.8570 - acc: 0.3504 - val_loss: 1.6144 - val_acc: 0.5904
# Epoch 2/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 1.2621 - acc: 0.6646Epoch 00001: val_loss improved from 1.61444 to 1.14329, saving model to saved_models/weights.best.Inc_model.hdf5
# 6680/6680 [==============================] - 1s - loss: 1.2612 - acc: 0.6645 - val_loss: 1.1433 - val_acc: 0.6922
# Epoch 3/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.8760 - acc: 0.7589Epoch 00002: val_loss improved from 1.14329 to 0.98843, saving model to saved_models/weights.best.Inc_model.hdf5
# 6680/6680 [==============================] - 1s - loss: 0.8776 - acc: 0.7581 - val_loss: 0.9884 - val_acc: 0.7126
# Epoch 4/500
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.7044 - acc: 0.8068Epoch 00003: val_loss improved from 0.98843 to 0.92562, saving model to saved_models/weights.best.Inc_model.hdf5
# 6680/6680 [==============================] - 1s - loss: 0.7060 - acc: 0.8049 - val_loss: 0.9256 - val_acc: 0.7389
# Epoch 5/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.5828 - acc: 0.8400Epoch 00004: val_loss improved from 0.92562 to 0.86767, saving model to saved_models/weights.best.Inc_model.hdf5
# 6680/6680 [==============================] - 1s - loss: 0.5810 - acc: 0.8407 - val_loss: 0.8677 - val_acc: 0.7425
# Epoch 6/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.4939 - acc: 0.8691Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.4960 - acc: 0.8692 - val_loss: 0.8806 - val_acc: 0.7521
# Epoch 7/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.4265 - acc: 0.8847Epoch 00006: val_loss improved from 0.86767 to 0.81079, saving model to saved_models/weights.best.Inc_model.hdf5
# 6680/6680 [==============================] - 1s - loss: 0.4261 - acc: 0.8849 - val_loss: 0.8108 - val_acc: 0.7617
# Epoch 8/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.3639 - acc: 0.9085Epoch 00007: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.3648 - acc: 0.9078 - val_loss: 0.8305 - val_acc: 0.7653
# Epoch 9/500
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.3303 - acc: 0.9134Epoch 00008: val_loss improved from 0.81079 to 0.77790, saving model to saved_models/weights.best.Inc_model.hdf5
# 6680/6680 [==============================] - 1s - loss: 0.3301 - acc: 0.9136 - val_loss: 0.7779 - val_acc: 0.7820
# Epoch 10/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.2707 - acc: 0.9327Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.2728 - acc: 0.9320 - val_loss: 0.7906 - val_acc: 0.7820
# Epoch 11/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.2460 - acc: 0.9389Epoch 00010: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.2457 - acc: 0.9389 - val_loss: 0.7801 - val_acc: 0.7784
# Epoch 12/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.2162 - acc: 0.9468Epoch 00011: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.2158 - acc: 0.9470 - val_loss: 0.8159 - val_acc: 0.7677
# Epoch 13/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.2036 - acc: 0.9520Epoch 00012: val_loss improved from 0.77790 to 0.76781, saving model to saved_models/weights.best.Inc_model.hdf5
# 6680/6680 [==============================] - 1s - loss: 0.2033 - acc: 0.9518 - val_loss: 0.7678 - val_acc: 0.7880
# Epoch 14/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.1722 - acc: 0.9589Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.1719 - acc: 0.9590 - val_loss: 0.7810 - val_acc: 0.7868
# Epoch 15/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.1510 - acc: 0.9642Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.1512 - acc: 0.9638 - val_loss: 0.7997 - val_acc: 0.7725
# Epoch 16/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.1345 - acc: 0.9722Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.1346 - acc: 0.9723 - val_loss: 0.7788 - val_acc: 0.7820
# Epoch 17/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.1239 - acc: 0.9712Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.1239 - acc: 0.9716 - val_loss: 0.7868 - val_acc: 0.7832
# Epoch 18/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.1141 - acc: 0.9735Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.1138 - acc: 0.9737 - val_loss: 0.7801 - val_acc: 0.7880
# Epoch 19/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0980 - acc: 0.9783Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0979 - acc: 0.9786 - val_loss: 0.7922 - val_acc: 0.7772
# Epoch 20/500
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0942 - acc: 0.9789Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0943 - acc: 0.9789 - val_loss: 0.8531 - val_acc: 0.7629
# Epoch 21/500
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0781 - acc: 0.9857Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0782 - acc: 0.9855 - val_loss: 0.8300 - val_acc: 0.7737
# Epoch 22/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0648 - acc: 0.9863Epoch 00021: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0674 - acc: 0.9858 - val_loss: 0.8135 - val_acc: 0.7880
# Epoch 23/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0694 - acc: 0.9834Epoch 00022: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0696 - acc: 0.9832 - val_loss: 0.7945 - val_acc: 0.7772
# Epoch 24/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0602 - acc: 0.9879Epoch 00023: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0603 - acc: 0.9879 - val_loss: 0.7941 - val_acc: 0.7844
# Epoch 25/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0598 - acc: 0.9868Epoch 00024: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0605 - acc: 0.9867 - val_loss: 0.8281 - val_acc: 0.7749
# Epoch 26/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0520 - acc: 0.9888Epoch 00025: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0521 - acc: 0.9888 - val_loss: 0.8007 - val_acc: 0.7832
# Epoch 27/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0531 - acc: 0.9894Epoch 00026: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0529 - acc: 0.9895 - val_loss: 0.8497 - val_acc: 0.7784
# Epoch 28/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0526 - acc: 0.9878Epoch 00027: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0522 - acc: 0.9880 - val_loss: 0.8477 - val_acc: 0.7808
# Epoch 29/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0386 - acc: 0.9931Epoch 00028: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0389 - acc: 0.9930 - val_loss: 0.8762 - val_acc: 0.7725
# Epoch 30/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0391 - acc: 0.9910Epoch 00029: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0393 - acc: 0.9910 - val_loss: 0.8139 - val_acc: 0.7880
# Epoch 31/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0423 - acc: 0.9905Epoch 00030: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0427 - acc: 0.9904 - val_loss: 0.9145 - val_acc: 0.7796
# Epoch 32/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0413 - acc: 0.9914Epoch 00031: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0411 - acc: 0.9916 - val_loss: 0.8703 - val_acc: 0.7856
# Epoch 33/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0322 - acc: 0.9936Epoch 00032: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0322 - acc: 0.9937 - val_loss: 0.8659 - val_acc: 0.7880
# Epoch 34/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0312 - acc: 0.9935Epoch 00033: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0311 - acc: 0.9936 - val_loss: 0.8633 - val_acc: 0.7880
# Epoch 35/500
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.0287 - acc: 0.9935Epoch 00034: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0287 - acc: 0.9936 - val_loss: 0.8657 - val_acc: 0.7844
# Epoch 36/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0304 - acc: 0.9938Epoch 00035: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0303 - acc: 0.9939 - val_loss: 0.8818 - val_acc: 0.7844
# Epoch 37/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0286 - acc: 0.9944Epoch 00036: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0287 - acc: 0.9943 - val_loss: 0.8806 - val_acc: 0.7832
# Epoch 38/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0283 - acc: 0.9935Epoch 00037: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0287 - acc: 0.9934 - val_loss: 0.9003 - val_acc: 0.7713
# Epoch 39/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0228 - acc: 0.9951Epoch 00038: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0228 - acc: 0.9952 - val_loss: 0.8965 - val_acc: 0.7737
# Epoch 40/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0228 - acc: 0.9956Epoch 00039: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0230 - acc: 0.9955 - val_loss: 0.9075 - val_acc: 0.7916
# Epoch 41/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0265 - acc: 0.9941Epoch 00040: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0268 - acc: 0.9939 - val_loss: 0.8943 - val_acc: 0.7856
# Epoch 42/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0220 - acc: 0.9957Epoch 00041: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0223 - acc: 0.9955 - val_loss: 0.9137 - val_acc: 0.7832
# Epoch 43/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0246 - acc: 0.9948Epoch 00042: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0249 - acc: 0.9946 - val_loss: 0.9919 - val_acc: 0.7629
# Epoch 44/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0216 - acc: 0.9959Epoch 00043: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0222 - acc: 0.9958 - val_loss: 0.9353 - val_acc: 0.7784
# Epoch 45/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0246 - acc: 0.9949Epoch 00044: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0243 - acc: 0.9951 - val_loss: 0.9390 - val_acc: 0.7701
# Epoch 46/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0187 - acc: 0.9950Epoch 00045: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0186 - acc: 0.9951 - val_loss: 0.9331 - val_acc: 0.7760
# Epoch 47/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0217 - acc: 0.9959Epoch 00046: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0216 - acc: 0.9958 - val_loss: 0.9497 - val_acc: 0.7725
# Epoch 48/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0197 - acc: 0.9962Epoch 00047: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0198 - acc: 0.9961 - val_loss: 0.9470 - val_acc: 0.7772
# Epoch 49/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0211 - acc: 0.9959Epoch 00048: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0221 - acc: 0.9958 - val_loss: 1.0021 - val_acc: 0.7737
# Epoch 50/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0184 - acc: 0.9962Epoch 00049: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0183 - acc: 0.9963 - val_loss: 0.9651 - val_acc: 0.7725
# Epoch 51/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0204 - acc: 0.9952Epoch 00050: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0204 - acc: 0.9952 - val_loss: 0.9972 - val_acc: 0.7677
# Epoch 52/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0181 - acc: 0.9957Epoch 00051: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0185 - acc: 0.9955 - val_loss: 1.0114 - val_acc: 0.7808
# Epoch 53/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0170 - acc: 0.9964Epoch 00052: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0170 - acc: 0.9964 - val_loss: 0.9641 - val_acc: 0.7772
# Epoch 54/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0174 - acc: 0.9966Epoch 00053: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0175 - acc: 0.9966 - val_loss: 1.0081 - val_acc: 0.7689
# Epoch 55/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0150 - acc: 0.9966Epoch 00054: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0151 - acc: 0.9966 - val_loss: 0.9441 - val_acc: 0.7808
# Epoch 56/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0199 - acc: 0.9956Epoch 00055: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0199 - acc: 0.9957 - val_loss: 0.9966 - val_acc: 0.7737
# Epoch 57/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0139 - acc: 0.9972Epoch 00056: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0138 - acc: 0.9973 - val_loss: 0.9010 - val_acc: 0.7844
# Epoch 58/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0155 - acc: 0.9963Epoch 00057: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0158 - acc: 0.9961 - val_loss: 0.9857 - val_acc: 0.7701
# Epoch 59/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0176 - acc: 0.9962Epoch 00058: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0173 - acc: 0.9963 - val_loss: 1.0100 - val_acc: 0.7844
# Epoch 60/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0151 - acc: 0.9968Epoch 00059: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0152 - acc: 0.9969 - val_loss: 0.9816 - val_acc: 0.7772
# Epoch 61/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0171 - acc: 0.9959Epoch 00060: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0171 - acc: 0.9960 - val_loss: 0.9341 - val_acc: 0.7796
# Epoch 62/500
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0150 - acc: 0.9965Epoch 00061: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0149 - acc: 0.9966 - val_loss: 0.9624 - val_acc: 0.7820
# Epoch 63/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0142 - acc: 0.9967Epoch 00062: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0141 - acc: 0.9967 - val_loss: 1.0180 - val_acc: 0.7856
# Epoch 64/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0133 - acc: 0.9973Epoch 00063: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0131 - acc: 0.9973 - val_loss: 0.9639 - val_acc: 0.7916
# Epoch 65/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0156 - acc: 0.9959Epoch 00064: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0155 - acc: 0.9960 - val_loss: 0.9455 - val_acc: 0.7880
# Epoch 66/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0115 - acc: 0.9968Epoch 00065: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0113 - acc: 0.9969 - val_loss: 0.9643 - val_acc: 0.7689
# Epoch 67/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0179 - acc: 0.9959Epoch 00066: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0177 - acc: 0.9960 - val_loss: 0.9889 - val_acc: 0.7701
# Epoch 68/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0126 - acc: 0.9973Epoch 00067: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0125 - acc: 0.9973 - val_loss: 0.9745 - val_acc: 0.7796
# Epoch 69/500
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0151 - acc: 0.9967Epoch 00068: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0150 - acc: 0.9967 - val_loss: 1.0109 - val_acc: 0.7796
# Epoch 70/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0143 - acc: 0.9973Epoch 00069: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0142 - acc: 0.9973 - val_loss: 0.9937 - val_acc: 0.7760
# Epoch 71/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0132 - acc: 0.9977Epoch 00070: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0132 - acc: 0.9978 - val_loss: 1.0059 - val_acc: 0.7796
# Epoch 72/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0100 - acc: 0.9979Epoch 00071: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0099 - acc: 0.9979 - val_loss: 0.9675 - val_acc: 0.7964
# Epoch 73/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0096 - acc: 0.9977Epoch 00072: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0096 - acc: 0.9978 - val_loss: 1.0286 - val_acc: 0.7844
# Epoch 74/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0133 - acc: 0.9972Epoch 00073: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0133 - acc: 0.9972 - val_loss: 0.9989 - val_acc: 0.7844
# Epoch 75/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0113 - acc: 0.9974Epoch 00074: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0117 - acc: 0.9972 - val_loss: 1.0497 - val_acc: 0.7653
# Epoch 76/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0130 - acc: 0.9985Epoch 00075: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0128 - acc: 0.9985 - val_loss: 0.9894 - val_acc: 0.7796
# Epoch 77/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0098 - acc: 0.9979Epoch 00076: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0098 - acc: 0.9978 - val_loss: 1.0226 - val_acc: 0.7737
# Epoch 78/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0097 - acc: 0.9979Epoch 00077: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0100 - acc: 0.9978 - val_loss: 1.0518 - val_acc: 0.7772
# Epoch 79/500
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.0144 - acc: 0.9974Epoch 00078: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0146 - acc: 0.9970 - val_loss: 1.0538 - val_acc: 0.7629
# Epoch 80/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0126 - acc: 0.9979Epoch 00079: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0124 - acc: 0.9979 - val_loss: 1.0623 - val_acc: 0.7713
# Epoch 81/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0097 - acc: 0.9983Epoch 00080: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0097 - acc: 0.9982 - val_loss: 1.1095 - val_acc: 0.7665
# Epoch 82/500
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.0108 - acc: 0.9965Epoch 00081: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0117 - acc: 0.9963 - val_loss: 1.0957 - val_acc: 0.7820
# Epoch 83/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0124 - acc: 0.9977Epoch 00082: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0122 - acc: 0.9978 - val_loss: 1.0088 - val_acc: 0.7713
# Epoch 84/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0123 - acc: 0.9973Epoch 00083: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0121 - acc: 0.9973 - val_loss: 1.0339 - val_acc: 0.7820
# Epoch 85/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0112 - acc: 0.9975Epoch 00084: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0110 - acc: 0.9976 - val_loss: 1.0634 - val_acc: 0.7725
# Epoch 86/500
# 6460/6680 [============================>.] - ETA: 0s - loss: 0.0109 - acc: 0.9974Epoch 00085: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0107 - acc: 0.9975 - val_loss: 1.0643 - val_acc: 0.7760
# Epoch 87/500
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.0082 - acc: 0.9981Epoch 00086: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0082 - acc: 0.9982 - val_loss: 1.0654 - val_acc: 0.7749
# Epoch 88/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0112 - acc: 0.9980Epoch 00087: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0110 - acc: 0.9981 - val_loss: 1.0919 - val_acc: 0.7808
# Epoch 89/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0130 - acc: 0.9969Epoch 00088: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0130 - acc: 0.9969 - val_loss: 1.1170 - val_acc: 0.7725
# Epoch 90/500
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0067 - acc: 0.9988Epoch 00089: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0067 - acc: 0.9988 - val_loss: 1.1222 - val_acc: 0.7713
# Epoch 91/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0125 - acc: 0.9971Epoch 00090: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0123 - acc: 0.9972 - val_loss: 1.1700 - val_acc: 0.7725
# Epoch 92/500
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.0104 - acc: 0.9975Epoch 00091: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0103 - acc: 0.9975 - val_loss: 1.0952 - val_acc: 0.7808
# Epoch 93/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0101 - acc: 0.9980Epoch 00092: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0100 - acc: 0.9981 - val_loss: 1.0885 - val_acc: 0.7737
# Epoch 94/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0119 - acc: 0.9977Epoch 00093: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0117 - acc: 0.9978 - val_loss: 1.1789 - val_acc: 0.7605
# Epoch 95/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0094 - acc: 0.9982Epoch 00094: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0093 - acc: 0.9982 - val_loss: 1.1225 - val_acc: 0.7760
# Epoch 96/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0084 - acc: 0.9985Epoch 00095: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0093 - acc: 0.9984 - val_loss: 1.0290 - val_acc: 0.7892
# Epoch 97/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0107 - acc: 0.9975Epoch 00096: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0105 - acc: 0.9976 - val_loss: 1.0796 - val_acc: 0.7820
# Epoch 98/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0119 - acc: 0.9982Epoch 00097: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0117 - acc: 0.9982 - val_loss: 1.1396 - val_acc: 0.7868
# Epoch 99/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0115 - acc: 0.9977Epoch 00098: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0115 - acc: 0.9976 - val_loss: 1.0637 - val_acc: 0.7737
# Epoch 100/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0100 - acc: 0.9974Epoch 00099: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0099 - acc: 0.9975 - val_loss: 1.1444 - val_acc: 0.7701
# Epoch 101/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0109 - acc: 0.9974Epoch 00100: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0108 - acc: 0.9975 - val_loss: 1.0984 - val_acc: 0.7677
# Epoch 102/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0121 - acc: 0.9979Epoch 00101: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0120 - acc: 0.9978 - val_loss: 1.1151 - val_acc: 0.7713
# Epoch 103/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0122 - acc: 0.9973Epoch 00102: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0122 - acc: 0.9973 - val_loss: 1.1888 - val_acc: 0.7593
# Epoch 104/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0070 - acc: 0.9983Epoch 00103: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0070 - acc: 0.9984 - val_loss: 1.1538 - val_acc: 0.7725
# Epoch 105/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0083 - acc: 0.9983Epoch 00104: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0082 - acc: 0.9984 - val_loss: 1.1500 - val_acc: 0.7701
# Epoch 106/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0109 - acc: 0.9975Epoch 00105: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0106 - acc: 0.9976 - val_loss: 1.1209 - val_acc: 0.7593
# Epoch 107/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0084 - acc: 0.9979Epoch 00106: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0095 - acc: 0.9978 - val_loss: 1.1385 - val_acc: 0.7641
# Epoch 108/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0135 - acc: 0.9971Epoch 00107: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0133 - acc: 0.9972 - val_loss: 1.1194 - val_acc: 0.7820
# Epoch 109/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0101 - acc: 0.9986Epoch 00108: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0100 - acc: 0.9987 - val_loss: 1.1685 - val_acc: 0.7629
# Epoch 110/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0038 - acc: 0.9988Epoch 00109: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0048 - acc: 0.9987 - val_loss: 1.1250 - val_acc: 0.7760
# Epoch 111/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0081 - acc: 0.9988Epoch 00110: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0080 - acc: 0.9988 - val_loss: 1.1880 - val_acc: 0.7749
# Epoch 112/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0081 - acc: 0.9983Epoch 00111: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0079 - acc: 0.9984 - val_loss: 1.1486 - val_acc: 0.7725
# Epoch 113/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0124 - acc: 0.9980Epoch 00112: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0123 - acc: 0.9981 - val_loss: 1.1456 - val_acc: 0.7784
# Epoch 114/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0107 - acc: 0.9980Epoch 00113: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0106 - acc: 0.9981 - val_loss: 1.1643 - val_acc: 0.7760
# Epoch 115/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0070 - acc: 0.9986Epoch 00114: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0069 - acc: 0.9987 - val_loss: 1.1380 - val_acc: 0.7796
# Epoch 116/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0081 - acc: 0.9986Epoch 00115: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0080 - acc: 0.9987 - val_loss: 1.1534 - val_acc: 0.7832
# Epoch 117/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0118 - acc: 0.9979Epoch 00116: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0116 - acc: 0.9979 - val_loss: 1.1988 - val_acc: 0.7713
# Epoch 118/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0073 - acc: 0.9985Epoch 00117: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0091 - acc: 0.9982 - val_loss: 1.2070 - val_acc: 0.7665
# Epoch 119/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0072 - acc: 0.9985Epoch 00118: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0071 - acc: 0.9985 - val_loss: 1.2313 - val_acc: 0.7784
# Epoch 120/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0121 - acc: 0.9980Epoch 00119: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0119 - acc: 0.9981 - val_loss: 1.2567 - val_acc: 0.7689
# Epoch 121/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0075 - acc: 0.9985Epoch 00120: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0100 - acc: 0.9982 - val_loss: 1.2126 - val_acc: 0.7713
# Epoch 122/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0081 - acc: 0.9983Epoch 00121: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0080 - acc: 0.9984 - val_loss: 1.1761 - val_acc: 0.7737
# Epoch 123/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0092 - acc: 0.9979Epoch 00122: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0092 - acc: 0.9979 - val_loss: 1.2608 - val_acc: 0.7605
# Epoch 124/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0092 - acc: 0.9983Epoch 00123: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0091 - acc: 0.9984 - val_loss: 1.1272 - val_acc: 0.7796
# Epoch 125/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0087 - acc: 0.9985Epoch 00124: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0085 - acc: 0.9985 - val_loss: 1.2383 - val_acc: 0.7689
# Epoch 126/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0106 - acc: 0.9971Epoch 00125: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0106 - acc: 0.9972 - val_loss: 1.2366 - val_acc: 0.7808
# Epoch 127/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0125 - acc: 0.9974Epoch 00126: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0124 - acc: 0.9975 - val_loss: 1.3004 - val_acc: 0.7665
# Epoch 128/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0127 - acc: 0.9980Epoch 00127: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0125 - acc: 0.9981 - val_loss: 1.2632 - val_acc: 0.7641
# Epoch 129/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0099 - acc: 0.9986Epoch 00128: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0097 - acc: 0.9987 - val_loss: 1.1863 - val_acc: 0.7677
# Epoch 130/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0104 - acc: 0.9982Epoch 00129: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0103 - acc: 0.9982 - val_loss: 1.2752 - val_acc: 0.7725
# Epoch 131/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0111 - acc: 0.9979Epoch 00130: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0110 - acc: 0.9979 - val_loss: 1.2468 - val_acc: 0.7784
# Epoch 132/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0130 - acc: 0.9970Epoch 00131: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0128 - acc: 0.9970 - val_loss: 1.2399 - val_acc: 0.7772
# Epoch 133/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0116 - acc: 0.9983Epoch 00132: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0116 - acc: 0.9984 - val_loss: 1.2842 - val_acc: 0.7772
# Epoch 134/500
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0091 - acc: 0.9982Epoch 00133: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0091 - acc: 0.9982 - val_loss: 1.2467 - val_acc: 0.7725
# Epoch 135/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0087 - acc: 0.9985Epoch 00134: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0086 - acc: 0.9985 - val_loss: 1.2570 - val_acc: 0.7725
# Epoch 136/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0136 - acc: 0.9975Epoch 00135: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0133 - acc: 0.9976 - val_loss: 1.2228 - val_acc: 0.7760
# Epoch 137/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0082 - acc: 0.9983Epoch 00136: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0082 - acc: 0.9984 - val_loss: 1.2404 - val_acc: 0.7593
# Epoch 138/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0092 - acc: 0.9983Epoch 00137: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0097 - acc: 0.9982 - val_loss: 1.2087 - val_acc: 0.7737
# Epoch 139/500
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.0090 - acc: 0.9983Epoch 00138: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0091 - acc: 0.9982 - val_loss: 1.2096 - val_acc: 0.7701
# Epoch 140/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0100 - acc: 0.9979Epoch 00139: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0098 - acc: 0.9979 - val_loss: 1.2002 - val_acc: 0.7844
# Epoch 141/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0077 - acc: 0.9988Epoch 00140: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0075 - acc: 0.9988 - val_loss: 1.2112 - val_acc: 0.7820
# Epoch 142/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0096 - acc: 0.9979Epoch 00141: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0096 - acc: 0.9979 - val_loss: 1.2226 - val_acc: 0.7796
# Epoch 143/500
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.0088 - acc: 0.9980Epoch 00142: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0102 - acc: 0.9978 - val_loss: 1.3091 - val_acc: 0.7760
# Epoch 144/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0059 - acc: 0.9982Epoch 00143: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0058 - acc: 0.9982 - val_loss: 1.3104 - val_acc: 0.7701
# Epoch 145/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0100 - acc: 0.9979Epoch 00144: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0098 - acc: 0.9979 - val_loss: 1.2503 - val_acc: 0.7856
# Epoch 146/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0110 - acc: 0.9983Epoch 00145: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0107 - acc: 0.9984 - val_loss: 1.2870 - val_acc: 0.7677
# Epoch 147/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0095 - acc: 0.9983Epoch 00146: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0093 - acc: 0.9984 - val_loss: 1.3318 - val_acc: 0.7689
# Epoch 148/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0138 - acc: 0.9982Epoch 00147: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0137 - acc: 0.9982 - val_loss: 1.2174 - val_acc: 0.7760
# Epoch 149/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0108 - acc: 0.9980Epoch 00148: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0106 - acc: 0.9981 - val_loss: 1.2644 - val_acc: 0.7772
# Epoch 150/500
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0113 - acc: 0.9983Epoch 00149: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0113 - acc: 0.9984 - val_loss: 1.2648 - val_acc: 0.7677
# Epoch 151/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0104 - acc: 0.9979Epoch 00150: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0102 - acc: 0.9979 - val_loss: 1.2724 - val_acc: 0.7784
# Epoch 152/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0091 - acc: 0.9980Epoch 00151: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0090 - acc: 0.9981 - val_loss: 1.2947 - val_acc: 0.7629
# Epoch 153/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0094 - acc: 0.9977Epoch 00152: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0093 - acc: 0.9978 - val_loss: 1.2949 - val_acc: 0.7665
# Epoch 154/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0105 - acc: 0.9983Epoch 00153: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0106 - acc: 0.9982 - val_loss: 1.3221 - val_acc: 0.7641
# Epoch 155/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0120 - acc: 0.9982Epoch 00154: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0118 - acc: 0.9982 - val_loss: 1.3044 - val_acc: 0.7521
# Epoch 156/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0089 - acc: 0.9985Epoch 00155: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0100 - acc: 0.9984 - val_loss: 1.3225 - val_acc: 0.7569
# Epoch 157/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0111 - acc: 0.9977Epoch 00156: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0135 - acc: 0.9975 - val_loss: 1.3552 - val_acc: 0.7689
# Epoch 158/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0111 - acc: 0.9985Epoch 00157: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0110 - acc: 0.9985 - val_loss: 1.3076 - val_acc: 0.7760
# Epoch 159/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0102 - acc: 0.9979Epoch 00158: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0105 - acc: 0.9978 - val_loss: 1.3339 - val_acc: 0.7665
# Epoch 160/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0089 - acc: 0.9985Epoch 00159: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0088 - acc: 0.9985 - val_loss: 1.2722 - val_acc: 0.7701
# Epoch 161/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0060 - acc: 0.9983Epoch 00160: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0059 - acc: 0.9984 - val_loss: 1.3113 - val_acc: 0.7832
# Epoch 162/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0114 - acc: 0.9982Epoch 00161: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0113 - acc: 0.9982 - val_loss: 1.3988 - val_acc: 0.7521
# Epoch 163/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0100 - acc: 0.9986Epoch 00162: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0097 - acc: 0.9987 - val_loss: 1.3697 - val_acc: 0.7641
# Epoch 164/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0079 - acc: 0.9985Epoch 00163: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0079 - acc: 0.9985 - val_loss: 1.4029 - val_acc: 0.7497
# Epoch 165/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0123 - acc: 0.9982Epoch 00164: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0121 - acc: 0.9982 - val_loss: 1.2975 - val_acc: 0.7725
# Epoch 166/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0117 - acc: 0.9982Epoch 00165: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0135 - acc: 0.9981 - val_loss: 1.4238 - val_acc: 0.7641
# Epoch 167/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0099 - acc: 0.9979Epoch 00166: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0098 - acc: 0.9979 - val_loss: 1.2940 - val_acc: 0.7772
# Epoch 168/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0105 - acc: 0.9975Epoch 00167: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0103 - acc: 0.9976 - val_loss: 1.3291 - val_acc: 0.7677
# Epoch 169/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0120 - acc: 0.9980Epoch 00168: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0117 - acc: 0.9981 - val_loss: 1.2323 - val_acc: 0.7713
# Epoch 170/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0084 - acc: 0.9983Epoch 00169: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0085 - acc: 0.9982 - val_loss: 1.3903 - val_acc: 0.7641
# Epoch 171/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0115 - acc: 0.9985Epoch 00170: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0113 - acc: 0.9985 - val_loss: 1.3127 - val_acc: 0.7725
# Epoch 172/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0072 - acc: 0.9982Epoch 00171: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0072 - acc: 0.9982 - val_loss: 1.3563 - val_acc: 0.7737
# Epoch 173/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0110 - acc: 0.9977Epoch 00172: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0110 - acc: 0.9978 - val_loss: 1.3685 - val_acc: 0.7629
# Epoch 174/500
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0097 - acc: 0.9983Epoch 00173: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0097 - acc: 0.9984 - val_loss: 1.3496 - val_acc: 0.7737
# Epoch 175/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0119 - acc: 0.9980Epoch 00174: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0117 - acc: 0.9981 - val_loss: 1.2974 - val_acc: 0.7928
# Epoch 176/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0072 - acc: 0.9980Epoch 00175: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0098 - acc: 0.9978 - val_loss: 1.4234 - val_acc: 0.7641
# Epoch 177/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0070 - acc: 0.9983Epoch 00176: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0078 - acc: 0.9982 - val_loss: 1.3363 - val_acc: 0.7605
# Epoch 178/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0056 - acc: 0.9988Epoch 00177: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0056 - acc: 0.9988 - val_loss: 1.2589 - val_acc: 0.7784
# Epoch 179/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0104 - acc: 0.9982Epoch 00178: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0103 - acc: 0.9982 - val_loss: 1.3346 - val_acc: 0.7749
# Epoch 180/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0119 - acc: 0.9976Epoch 00179: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0118 - acc: 0.9976 - val_loss: 1.3308 - val_acc: 0.7772
# Epoch 181/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0076 - acc: 0.9983Epoch 00180: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0075 - acc: 0.9984 - val_loss: 1.2773 - val_acc: 0.7868
# Epoch 182/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0081 - acc: 0.9982Epoch 00181: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0079 - acc: 0.9982 - val_loss: 1.3782 - val_acc: 0.7677
# Epoch 183/500
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0062 - acc: 0.9989Epoch 00182: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0062 - acc: 0.9990 - val_loss: 1.4986 - val_acc: 0.7581
# Epoch 184/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0114 - acc: 0.9977Epoch 00183: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0112 - acc: 0.9978 - val_loss: 1.4273 - val_acc: 0.7749
# Epoch 185/500
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.0144 - acc: 0.9975Epoch 00184: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0139 - acc: 0.9976 - val_loss: 1.3975 - val_acc: 0.7689
# Epoch 186/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0097 - acc: 0.9985Epoch 00185: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0101 - acc: 0.9982 - val_loss: 1.4017 - val_acc: 0.7641
# Epoch 187/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0120 - acc: 0.9973Epoch 00186: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0118 - acc: 0.9973 - val_loss: 1.4477 - val_acc: 0.7593
# Epoch 188/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0139 - acc: 0.9977Epoch 00187: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0136 - acc: 0.9978 - val_loss: 1.3464 - val_acc: 0.7784
# Epoch 189/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0077 - acc: 0.9983Epoch 00188: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0100 - acc: 0.9982 - val_loss: 1.3512 - val_acc: 0.7725
# Epoch 190/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0116 - acc: 0.9983Epoch 00189: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0118 - acc: 0.9982 - val_loss: 1.3576 - val_acc: 0.7760
# Epoch 191/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0088 - acc: 0.9983Epoch 00190: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0087 - acc: 0.9984 - val_loss: 1.4066 - val_acc: 0.7569
# Epoch 192/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0113 - acc: 0.9975Epoch 00191: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0119 - acc: 0.9975 - val_loss: 1.4050 - val_acc: 0.7617
# Epoch 193/500
# ...
# 6680/6680 [==============================] - 1s - loss: 0.0097 - acc: 0.9990 - val_loss: 1.8691 - val_acc: 0.7641
# Epoch 437/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0102 - acc: 0.9986Epoch 00436: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0100 - acc: 0.9987 - val_loss: 1.8085 - val_acc: 0.7665
# Epoch 438/500
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0095 - acc: 0.9976Epoch 00437: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0094 - acc: 0.9976 - val_loss: 1.6812 - val_acc: 0.7725
# Epoch 439/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0052 - acc: 0.9991Epoch 00438: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0051 - acc: 0.9991 - val_loss: 1.6197 - val_acc: 0.7629
# Epoch 440/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0127 - acc: 0.9985Epoch 00439: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0125 - acc: 0.9985 - val_loss: 1.7367 - val_acc: 0.7725
# Epoch 441/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0113 - acc: 0.9982Epoch 00440: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0110 - acc: 0.9982 - val_loss: 1.7781 - val_acc: 0.7725
# Epoch 442/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0125 - acc: 0.9986Epoch 00441: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0122 - acc: 0.9987 - val_loss: 1.7746 - val_acc: 0.7760
# Epoch 443/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0111 - acc: 0.9983Epoch 00442: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0109 - acc: 0.9984 - val_loss: 1.7391 - val_acc: 0.7521
# Epoch 444/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0102 - acc: 0.9988Epoch 00443: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0100 - acc: 0.9988 - val_loss: 1.8106 - val_acc: 0.7593
# Epoch 445/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0103 - acc: 0.9986Epoch 00444: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0104 - acc: 0.9985 - val_loss: 1.7629 - val_acc: 0.7725
# Epoch 446/500
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.0092 - acc: 0.9989Epoch 00445: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0107 - acc: 0.9988 - val_loss: 1.7056 - val_acc: 0.7772
# Epoch 447/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0121 - acc: 0.9980Epoch 00446: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0120 - acc: 0.9981 - val_loss: 1.8236 - val_acc: 0.7689
# Epoch 448/500
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.0094 - acc: 0.9988Epoch 00447: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0091 - acc: 0.9988 - val_loss: 1.8419 - val_acc: 0.7725
# Epoch 449/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0126 - acc: 0.9989Epoch 00448: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0126 - acc: 0.9990 - val_loss: 1.8132 - val_acc: 0.7725
# Epoch 450/500
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.0098 - acc: 0.9992Epoch 00449: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0095 - acc: 0.9993 - val_loss: 1.8412 - val_acc: 0.7689
# Epoch 451/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0079 - acc: 0.9988Epoch 00450: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0078 - acc: 0.9988 - val_loss: 1.7857 - val_acc: 0.7713
# Epoch 452/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0128 - acc: 0.9980Epoch 00451: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0126 - acc: 0.9981 - val_loss: 1.7119 - val_acc: 0.7796
# Epoch 453/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0097 - acc: 0.9983Epoch 00452: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0096 - acc: 0.9984 - val_loss: 1.8292 - val_acc: 0.7533
# Epoch 454/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0143 - acc: 0.9978Epoch 00453: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0140 - acc: 0.9979 - val_loss: 1.7621 - val_acc: 0.7689
# Epoch 455/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0129 - acc: 0.9977Epoch 00454: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0126 - acc: 0.9978 - val_loss: 1.7308 - val_acc: 0.7832
# Epoch 456/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0128 - acc: 0.9985Epoch 00455: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0126 - acc: 0.9985 - val_loss: 1.8497 - val_acc: 0.7593
# Epoch 457/500
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.0133 - acc: 0.9978Epoch 00456: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0129 - acc: 0.9979 - val_loss: 1.8403 - val_acc: 0.7581
# Epoch 458/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0120 - acc: 0.9986Epoch 00457: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0117 - acc: 0.9987 - val_loss: 1.8606 - val_acc: 0.7593
# Epoch 459/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0076 - acc: 0.9983Epoch 00458: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0075 - acc: 0.9984 - val_loss: 1.8323 - val_acc: 0.7545
# Epoch 460/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0088 - acc: 0.9986Epoch 00459: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0088 - acc: 0.9987 - val_loss: 1.8609 - val_acc: 0.7653
# Epoch 461/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0106 - acc: 0.9986Epoch 00460: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0103 - acc: 0.9987 - val_loss: 1.8704 - val_acc: 0.7689
# Epoch 462/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0121 - acc: 0.9986Epoch 00461: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0120 - acc: 0.9987 - val_loss: 1.8351 - val_acc: 0.7641
# Epoch 463/500
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0094 - acc: 0.9986Epoch 00462: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0093 - acc: 0.9987 - val_loss: 1.9630 - val_acc: 0.7653
# Epoch 464/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0088 - acc: 0.9992Epoch 00463: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0086 - acc: 0.9993 - val_loss: 1.8049 - val_acc: 0.7641
# Epoch 465/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0139 - acc: 0.9982Epoch 00464: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0136 - acc: 0.9982 - val_loss: 1.8280 - val_acc: 0.7772
# Epoch 466/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0118 - acc: 0.9983Epoch 00465: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0114 - acc: 0.9984 - val_loss: 1.7814 - val_acc: 0.7605
# Epoch 467/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0116 - acc: 0.9983Epoch 00466: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0115 - acc: 0.9984 - val_loss: 1.7596 - val_acc: 0.7713
# Epoch 468/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0115 - acc: 0.9985Epoch 00467: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0114 - acc: 0.9985 - val_loss: 1.7822 - val_acc: 0.7641
# Epoch 469/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0131 - acc: 0.9988Epoch 00468: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0128 - acc: 0.9988 - val_loss: 1.7982 - val_acc: 0.7784
# Epoch 470/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0106 - acc: 0.9991Epoch 00469: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0116 - acc: 0.9990 - val_loss: 1.7237 - val_acc: 0.7641
# Epoch 471/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0095 - acc: 0.9983Epoch 00470: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0093 - acc: 0.9984 - val_loss: 1.8767 - val_acc: 0.7641
# Epoch 472/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0100 - acc: 0.9983Epoch 00471: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0107 - acc: 0.9982 - val_loss: 1.8752 - val_acc: 0.7593
# Epoch 473/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0122 - acc: 0.9982Epoch 00472: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0120 - acc: 0.9982 - val_loss: 1.8608 - val_acc: 0.7533
# Epoch 474/500
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0117 - acc: 0.9985Epoch 00473: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0115 - acc: 0.9985 - val_loss: 1.8333 - val_acc: 0.7605
# Epoch 475/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0101 - acc: 0.9983Epoch 00474: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0100 - acc: 0.9984 - val_loss: 1.8522 - val_acc: 0.7820
# Epoch 476/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0094 - acc: 0.9983Epoch 00475: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0093 - acc: 0.9984 - val_loss: 1.8391 - val_acc: 0.7677
# Epoch 477/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0118 - acc: 0.9988Epoch 00476: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0117 - acc: 0.9988 - val_loss: 1.8166 - val_acc: 0.7784
# Epoch 478/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0117 - acc: 0.9983Epoch 00477: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0115 - acc: 0.9984 - val_loss: 1.9167 - val_acc: 0.7557
# Epoch 479/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0112 - acc: 0.9985Epoch 00478: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0110 - acc: 0.9985 - val_loss: 1.7674 - val_acc: 0.7617
# Epoch 480/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0099 - acc: 0.9991Epoch 00479: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0097 - acc: 0.9991 - val_loss: 1.8599 - val_acc: 0.7569
# Epoch 481/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0117 - acc: 0.9986Epoch 00480: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0114 - acc: 0.9987 - val_loss: 1.8664 - val_acc: 0.7760
# Epoch 482/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0099 - acc: 0.9989Epoch 00481: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0097 - acc: 0.9990 - val_loss: 1.6527 - val_acc: 0.7772
# Epoch 483/500
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0124 - acc: 0.9983Epoch 00482: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0123 - acc: 0.9984 - val_loss: 1.7528 - val_acc: 0.7856
# Epoch 484/500
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0115 - acc: 0.9985Epoch 00483: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0115 - acc: 0.9985 - val_loss: 1.7897 - val_acc: 0.7808
# Epoch 485/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0124 - acc: 0.9982Epoch 00484: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0122 - acc: 0.9982 - val_loss: 1.7771 - val_acc: 0.7737
# Epoch 486/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0163 - acc: 0.9982Epoch 00485: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0160 - acc: 0.9982 - val_loss: 1.8047 - val_acc: 0.7701
# Epoch 487/500
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0122 - acc: 0.9985Epoch 00486: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0122 - acc: 0.9985 - val_loss: 1.7974 - val_acc: 0.7617
# Epoch 488/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0161 - acc: 0.9986Epoch 00487: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0158 - acc: 0.9987 - val_loss: 1.8558 - val_acc: 0.7653
# Epoch 489/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0117 - acc: 0.9988Epoch 00488: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0115 - acc: 0.9988 - val_loss: 1.7406 - val_acc: 0.7832
# Epoch 490/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0125 - acc: 0.9985Epoch 00489: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0123 - acc: 0.9985 - val_loss: 1.8570 - val_acc: 0.7725
# Epoch 491/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0118 - acc: 0.9988Epoch 00490: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0115 - acc: 0.9988 - val_loss: 1.8170 - val_acc: 0.7677
# Epoch 492/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0086 - acc: 0.9985Epoch 00491: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0084 - acc: 0.9985 - val_loss: 1.7212 - val_acc: 0.7713
# Epoch 493/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0131 - acc: 0.9986Epoch 00492: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0131 - acc: 0.9985 - val_loss: 1.8241 - val_acc: 0.7749
# Epoch 494/500
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0095 - acc: 0.9989Epoch 00493: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0093 - acc: 0.9990 - val_loss: 1.8801 - val_acc: 0.7629
# Epoch 495/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0099 - acc: 0.9988Epoch 00494: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0098 - acc: 0.9988 - val_loss: 1.7926 - val_acc: 0.7784
# Epoch 496/500
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0097 - acc: 0.9985Epoch 00495: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0095 - acc: 0.9985 - val_loss: 1.8531 - val_acc: 0.7665
# Epoch 497/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0096 - acc: 0.9988Epoch 00496: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0094 - acc: 0.9988 - val_loss: 1.7803 - val_acc: 0.7784
# Epoch 498/500
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0065 - acc: 0.9986Epoch 00497: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0064 - acc: 0.9987 - val_loss: 1.9189 - val_acc: 0.7485
# Epoch 499/500
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0090 - acc: 0.9983Epoch 00498: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0089 - acc: 0.9984 - val_loss: 1.7682 - val_acc: 0.7725
# Epoch 500/500
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0131 - acc: 0.9986Epoch 00499: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0128 - acc: 0.9987 - val_loss: 1.7669 - val_acc: 0.7749

# %%
### TODO: 加载具有最佳验证loss的模型权重
Inc_model.load_weights('saved_models/weights.best.Inc_model.hdf5')

# %% [markdown]
# ---
#
# ### 【练习】测试模型
#
# <a id='question8'></a>
#
# ### __问题 8:__
#
# 在狗图像的测试数据集上试用你的模型。确保测试准确率大于60%。

# %%
### TODO: 在测试集上计算分类准确率
Inc_predictions = [np.argmax(Inc_model.predict(np.expand_dims(feature, axis=0))) for feature in test_Inception]

# report test accuracy
test_accuracy = 100*np.sum(np.array(Inc_predictions)==np.argmax(test_targets, axis=1))/len(Inc_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
Inc_predictions = [np.argmax(Inc_model.predict(np.expand_dims(feature, axis=0))) for feature in test_Inception]
# Out:
# Test accuracy: 76.4354%

# %% [markdown]
# ---
#
# ### 【练习】使用模型测试狗的品种
#
#
# 实现一个函数，它的输入为图像路径，功能为预测对应图像的类别，输出为你模型预测出的狗类别（`Affenpinscher`, `Afghan_hound` 等）。
#
# 与步骤5中的模拟函数类似，你的函数应当包含如下三个步骤：
#
# 1. 根据选定的模型载入图像特征（bottleneck features）
# 2. 将图像特征输输入到你的模型中，并返回预测向量。注意，在该向量上使用 argmax 函数可以返回狗种类的序号。
# 3. 使用在步骤0中定义的 `dog_names` 数组来返回对应的狗种类名称。
#
# 提取图像特征过程中使用到的函数可以在 `extract_bottleneck_features.py` 中找到。同时，他们应已在之前的代码块中被导入。根据你选定的 CNN 网络，你可以使用 `extract_{network}` 函数来获得对应的图像特征，其中 `{network}` 代表 `VGG19`, `Resnet50`, `InceptionV3`, 或 `Xception` 中的一个。
#
# ---
#
# <a id='question9'></a>
#
# ### __问题 9:__

# %%
### TODO: 写一个函数，该函数将图像的路径作为输入
### 然后返回此模型所预测的狗的品种
def Inc_predict_breed(img_path):
    bottleneck_feature = extract_VGG19(path_to_tensor(img_path))
    predicted_vector = Inc_model.predict(bottleneck_feature)
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
#
# <a id='step6'></a>
# ## 步骤 6: 完成你的算法
#
#
#
# 实现一个算法，它的输入为图像的路径，它能够区分图像是否包含一个人、狗或两者都不包含，然后：
#
# - 如果从图像中检测到一只__狗__，返回被预测的品种。
# - 如果从图像中检测到__人__，返回最相像的狗品种。
# - 如果两者都不能在图像中检测到，输出错误提示。
#
# 我们非常欢迎你来自己编写检测图像中人类与狗的函数，你可以随意地使用上方完成的 `face_detector` 和 `dog_detector` 函数。你__需要__在步骤5使用你的CNN来预测狗品种。
#
# 下面提供了算法的示例输出，但你可以自由地设计自己的模型！
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
#
#
# <a id='question10'></a>
#
# ### __问题 10:__
#
# 在下方代码块中完成你的代码。
#
# ---

# %%
### TODO: 设计你的算法
### 自由地使用所需的代码单元数吧
def predict_breed_or_resemblance(img_path):
    creature = None
    message = None
    breed = None
    if dog_detector(img_path):
        creature = "这是狗"
        message = "它的品种看起来像"
    
    if face_detector(img_path):
        creature = "这是一个人"
        message = "看起来像："
    
    if not creature:
        raise NeitherDogNorHumanError("这看起来既不像一个人，也不像一条狗")
    
    breed = Inc_predict_breed(img_path)
    return "{}! {} ... {}".format(creature, message, breed)

# %% [markdown]
# ---
# <a id='step7'></a>
# ## 步骤 7: 测试你的算法
#
# 在这个部分中，你将尝试一下你的新算法！算法认为__你__看起来像什么类型的狗？如果你有一只狗，它可以准确地预测你的狗的品种吗？如果你有一只猫，它会将你的猫误判为一只狗吗？
#
#
# <a id='question11'></a>
#
# ### __问题 11:__
#
# 在下方编写代码，用至少6张现实中的图片来测试你的算法。你可以使用任意照片，不过请至少使用两张人类图片（要征得当事人同意哦）和两张狗的图片。
# 同时请回答如下问题：
#
# 1. 输出结果比你预想的要好吗 :) ？或者更糟 :( ？
# 2. 提出至少三点改进你的模型的想法。

# %% [markdown]
# 输出的结果并没有想象中的好，不过也不算太糟糕，对于人类和狗都能直接区分开来，不过在狗狗品种的准确率上并不是很高。
# 一些改进的想法：
# 1、在建立模型上进行更改，选择更高效的模型来进行预测
# 2、设置一个最低阀值，如果不是特殊的必要要求，即使这张照片被分类成了狗，但是如果这个概率太低，应该直接输出这既不是狗也不算人，然后再重新运算，这样或许回提高一些准确率。
# 3、第三点其实并不是很能想出来，如果储存之前预测的概率，并且基于最高的概率来区分狗和人，这样应该也能提高一点的准确率

# %%
## TODO: 在你的电脑上，在步骤6中，至少在6张图片上运行你的算法。
## 自由地使用所需的代码单元数吧
me = "./1.jpg"

print(predict_breed_or_resemblance("./images/American_water_spaniel_00648.jpg"))
print(predict_breed_or_resemblance(me))
print(predict_breed_or_resemblance("./3.jpg"))
print(predict_breed_or_resemblance("./2.jpg"))
print(predict_breed_or_resemblance("./images/Curly-coated_retriever_03896.jpg"))
print(predict_breed_or_resemblance("./images/Labrador_retriever_06449.jpg"))
# Out:
# 这是狗! 它的品种看起来像 ... Curly-coated_retriever
# 这是一个人! 看起来像： ... Kerry_blue_terrier
# 这是狗! 它的品种看起来像 ... Golden_retriever
# 这是一个人! 看起来像： ... Yorkshire_terrier
# 这是狗! 它的品种看起来像 ... Curly-coated_retriever
# 这是狗! 它的品种看起来像 ... Labrador_retriever

# %% [markdown]
# **注意: 当你写完了所有的代码，并且回答了所有的问题。你就可以把你的 iPython Notebook 导出成 HTML 文件。你可以在菜单栏，这样导出File -> Download as -> HTML (.html)把这个 HTML 和这个 iPython notebook 一起做为你的作业提交。**
